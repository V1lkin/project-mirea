# %%
# Установка всех требуемых библиотек
# !python -m pip install pandas
# !python -m pip install requests
# !python -m pip install scikit-learn
# Out:
#   Cell In[4], line 2
#     python -m pip install pandas
#               ^
# SyntaxError: invalid syntax

# %%
# !pip install pandas
# !pip install requests
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\omen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (2.0.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\omen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\omen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\omen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\omen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\OMEN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl (99 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2023.11.17 charset-normalizer-3.3.2 idna-3.4 requests-2.31.0 urllib3-2.1.0
#   WARNING: The script normalizer.exe is installed in 'C:\Users\OMEN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\OMEN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\omen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from scikit-learn) (1.24.4)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting scipy>=1.5.0
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.2.0
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\OMEN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
# Импортируем все необходимые библиотеки
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import Locator
from datetime import datetime, timedelta
import numpy as np
import requests
import string
import json
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from urllib.parse import unquote

# %%
class SteamParser:
    _steamcoockie: str
    # currency - id валюты. 5 - RUB
    # country - локализация текста
    # market_hash_name - название товара
    steam_item_url = "https://steamcommunity.com/market/listings/{app_id}/{name}"
    histogram_url = "https://steamcommunity.com/market/itemordershistogram?country=RU&language=english&currency=5&item_nameid={item_id}&two_factor=0"
    item_id_search = "Market_LoadOrderSpread( "

    search_history_start = "var line1="
    search_history_end = ";\r\n\t\t\tg_timePriceHistoryEarliest = new Date();"

    @classmethod
    def get_item(cls, name, app_id=730):
        resp = requests.get(cls.steam_item_url.format(app_id=app_id, name=name))
        return Item(name, app_id, resp)

    @classmethod
    def get_order_histogram(cls, item_id):
        resp = requests.get(cls.histogram_url.format(item_id=item_id))
        return resp.json()

    @classmethod
    def get_item_id(cls, resp: requests.Response):
        index = resp.text.find(cls.item_id_search) + len(cls.item_id_search)
        item_id = ""
        while resp.text[index] in string.digits:
            item_id += resp.text[index]
            index += 1
        return item_id
    
    @classmethod
    def get_price_history(cls, resp: requests.Response):
        start_index = resp.text.find(cls.search_history_start) + len(cls.search_history_start)
        end_index = resp.text.find(cls.search_history_end)
        return json.loads(resp.text[start_index:end_index])

class Item:
    _resp: requests.Response
    id: str
    price_history: object
    histogram: object
    
    def __init__(self, name: str, app_id: int, resp: requests.Response):
        self._resp = resp
        self.id = SteamParser.get_item_id(resp)
        self.price_history = SteamParser.get_price_history(self._resp)
        self.histogram = SteamParser.get_order_histogram(self.id)

# %%
item = SteamParser.get_item("Revolution Case", 730)

# %%
item.price_history
# Out:
# [['Feb 10 2023 01: +0', 13.462, '79764'],
#  ['Feb 11 2023 01: +0', 8.041, '79886'],
#  ['Feb 12 2023 01: +0', 6.889, '78300'],
#  ['Feb 13 2023 01: +0', 6.96, '58451'],
#  ['Feb 14 2023 01: +0', 5.986, '57769'],
#  ['Feb 15 2023 01: +0', 5.549, '57410'],
#  ['Feb 16 2023 01: +0', 5.544, '59648'],
#  ['Feb 17 2023 01: +0', 4.744, '67413'],
#  ['Feb 18 2023 01: +0', 4.303, '77269'],
#  ['Feb 19 2023 01: +0', 3.502, '76360'],
#  ['Feb 20 2023 01: +0', 3.131, '64885'],
#  ['Feb 21 2023 01: +0', 3.021, '61645'],
#  ['Feb 22 2023 01: +0', 3.034, '61591'],
#  ['Feb 23 2023 01: +0', 3.005, '63411'],
#  ['Feb 24 2023 01: +0', 3.046, '66744'],
#  ['Feb 25 2023 01: +0', 2.902, '70867'],
#  ['Feb 26 2023 01: +0', 2.654, '75588'],
#  ['Feb 27 2023 01: +0', 2.595, '67384'],
#  ['Feb 28 2023 01: +0', 2.657, '61965'],
#  ['Mar 01 2023 01: +0', 2.735, '60367'],
#  ['Mar 02 2023 01: +0', 2.75, '60819'],
#  ['Mar 03 2023 01: +0', 2.801, '67046'],
#  ['Mar 04 2023 01: +0', 2.726, '76394'],
#  ['Mar 05 2023 01: +0', 2.632, '75587'],
#  ['Mar 06 2023 01: +0', 2.52, '68017'],
#  ['Mar 07 2023 01: +0', 2.502, '68332'],
#  ['Mar 08 2023 01: +0', 2.512, '65406'],
#  ['Mar 09 2023 01: +0', 2.597, '67167'],
#  ['Mar 10 2023 01: +0', 2.721, '73206'],
#  ['Mar 11 2023 01: +0', 2.709, '79307'],
#  ['Mar 12 2023 01: +0', 2.629, '76768'],
#  ['Mar 13 2023 01: +0', 2.527, '65853'],
#  ['Mar 14 2023 01: +0', 2.499, '67371'],
#  ['Mar 15 2023 01: +0', 2.545, '70343'],
#  ['Mar 16 2023 01: +0', 2.549, '69531'],
#  ['Mar 17 2023 01: +0', 2.562, '77763'],
#  ['Mar 18 2023 01: +0', 2.552, '82713'],
#  ['Mar 19 2023 01: +0', 2.463, '82736'],
#  ['Mar 20 2023 01: +0', 2.357, '69934'],
#  ['Mar 21 2023 01: +0', 2.306, '72892'],
#  ['Mar 22 2023 01: +0', 2.316, '90766'],
#  ['Mar 23 2023 01: +0', 2.575, '104374'],
#  ['Mar 24 2023 01: +0', 2.761, '99602'],
#  ['Mar 25 2023 01: +0', 2.801, '99990'],
#  ['Mar 26 2023 01: +0', 2.815, '103554'],
#  ['Mar 27 2023 01: +0', 2.82, '89886'],
#  ['Mar 28 2023 01: +0', 2.827, '90452'],
#  ['Mar 29 2023 01: +0', 2.901, '82826'],
#  ['Mar 30 2023 01: +0', 2.98, '74287'],
#  ['Mar 31 2023 01: +0', 3.145, '79041'],
#  ['Apr 01 2023 01: +0', 3.195, '98081'],
#  ['Apr 02 2023 01: +0', 2.948, '106255'],
#  ['Apr 03 2023 01: +0', 2.933, '96752'],
#  ['Apr 04 2023 01: +0', 3.026, '85896'],
#  ['Apr 05 2023 01: +0', 3.103, '83144'],
#  ['Apr 06 2023 01: +0', 3.226, '92027'],
#  ['Apr 07 2023 01: +0', 3.39, '85076'],
#  ['Apr 08 2023 01: +0', 3.462, '88723'],
#  ['Apr 09 2023 01: +0', 3.345, '98952'],
#  ['Apr 10 2023 01: +0', 3.344, '92309'],
#  ['Apr 11 2023 01: +0', 3.287, '84992'],
#  ['Apr 12 2023 01: +0', 3.276, '86219'],
#  ['Apr 13 2023 01: +0', 3.366, '84763'],
#  ['Apr 14 2023 01: +0', 3.531, '83214'],
#  ['Apr 15 2023 01: +0', 3.623, '74876'],
#  ['Apr 16 2023 01: +0', 3.566, '83316'],
#  ['Apr 17 2023 01: +0', 3.523, '94262'],
#  ['Apr 18 2023 01: +0', 3.522, '78165'],
#  ['Apr 19 2023 01: +0', 3.555, '79053'],
#  ['Apr 20 2023 01: +0', 3.511, '100303'],
#  ['Apr 21 2023 01: +0', 3.511, '104759'],
#  ['Apr 22 2023 01: +0', 3.471, '101273'],
#  ['Apr 23 2023 01: +0', 3.32, '99971'],
#  ['Apr 24 2023 01: +0', 3.169, '93098'],
#  ['Apr 25 2023 01: +0', 2.945, '107142'],
#  ['Apr 26 2023 01: +0', 2.724, '90786'],
#  ['Apr 27 2023 01: +0', 2.726, '94818'],
#  ['Apr 28 2023 01: +0', 2.842, '92741'],
#  ['Apr 29 2023 01: +0', 2.839, '92746'],
#  ['Apr 30 2023 01: +0', 2.771, '93857'],
#  ['May 01 2023 01: +0', 2.604, '86637'],
#  ['May 02 2023 01: +0', 2.532, '89790'],
#  ['May 03 2023 01: +0', 2.566, '80621'],
#  ['May 04 2023 01: +0', 2.545, '82751'],
#  ['May 05 2023 01: +0', 2.448, '100847'],
#  ['May 06 2023 01: +0', 2.437, '94663'],
#  ['May 07 2023 01: +0', 2.304, '97420'],
#  ['May 08 2023 01: +0', 2.182, '88127'],
#  ['May 09 2023 01: +0', 2.151, '84706'],
#  ['May 10 2023 01: +0', 2.274, '80062'],
#  ['May 11 2023 01: +0', 2.261, '77075'],
#  ['May 12 2023 01: +0', 2.242, '83855'],
#  ['May 13 2023 01: +0', 2.218, '87884'],
#  ['May 14 2023 01: +0', 2.116, '85105'],
#  ['May 15 2023 01: +0', 2.056, '78921'],
#  ['May 16 2023 01: +0', 2.04, '80190'],
#  ['May 17 2023 01: +0', 2.036, '79228'],
#  ['May 18 2023 01: +0', 2.023, '78314'],
#  ['May 19 2023 01: +0', 1.995, '83342'],
#  ['May 20 2023 01: +0', 1.967, '84318'],
#  ['May 21 2023 01: +0', 1.933, '88627'],
#  ['May 22 2023 01: +0', 1.908, '80095'],
#  ['May 23 2023 01: +0', 1.887, '80347'],
#  ['May 24 2023 01: +0', 1.89, '81266'],
#  ['May 25 2023 01: +0', 1.909, '85120'],
#  ['May 26 2023 01: +0', 1.931, '88857'],
#  ['May 27 2023 01: +0', 1.955, '89419'],
#  ['May 28 2023 01: +0', 1.944, '84591'],
#  ['May 29 2023 01: +0', 1.953, '83474'],
#  ['May 30 2023 01: +0', 1.949, '75595'],
#  ['May 31 2023 01: +0', 1.958, '79708'],
#  ['Jun 01 2023 01: +0', 2, '80763'],
#  ['Jun 02 2023 01: +0', 2.013, '81724'],
#  ['Jun 03 2023 01: +0', 2.004, '85880'],
#  ['Jun 04 2023 01: +0', 1.998, '86725'],
#  ['Jun 05 2023 01: +0', 1.956, '73771'],
#  ['Jun 06 2023 01: +0', 1.926, '78728'],
#  ['Jun 07 2023 01: +0', 1.91, '78859'],
#  ['Jun 08 2023 01: +0', 1.923, '86984'],
#  ['Jun 09 2023 01: +0', 1.965, '77755'],
#  ['Jun 10 2023 01: +0', 2.142, '100806'],
#  ['Jun 11 2023 01: +0', 2.144, '66614'],
#  ['Jun 12 2023 01: +0', 2.146, '60077'],
#  ['Jun 13 2023 01: +0', 2.172, '51812'],
#  ['Jun 14 2023 01: +0', 2.041, '91963'],
#  ['Jun 15 2023 01: +0', 1.967, '83393'],
#  ['Jun 16 2023 01: +0', 2.022, '78038'],
#  ['Jun 17 2023 01: +0', 2.106, '70391'],
#  ['Jun 18 2023 01: +0', 2.114, '61287'],
#  ['Jun 19 2023 01: +0', 2.083, '52261'],
#  ['Jun 20 2023 01: +0', 2.019, '51138'],
#  ['Jun 21 2023 01: +0', 1.947, '91698'],
#  ['Jun 22 2023 01: +0', 1.886, '78011'],
#  ['Jun 23 2023 01: +0', 1.846, '83825'],
#  ['Jun 24 2023 01: +0', 1.828, '70074'],
#  ['Jun 25 2023 01: +0', 1.839, '60382'],
#  ['Jun 26 2023 01: +0', 1.808, '52307'],
#  ['Jun 27 2023 01: +0', 1.785, '48901'],
#  ['Jun 28 2023 01: +0', 1.635, '97155'],
#  ['Jun 29 2023 01: +0', 1.461, '87453'],
#  ['Jun 30 2023 01: +0', 1.427, '86215'],
#  ['Jul 01 2023 01: +0', 1.459, '70896'],
#  ['Jul 02 2023 01: +0', 1.44, '65417'],
#  ['Jul 03 2023 01: +0', 1.413, '55711'],
#  ['Jul 04 2023 01: +0', 1.455, '56084'],
#  ['Jul 05 2023 01: +0', 1.363, '92614'],
#  ['Jul 06 2023 01: +0', 1.266, '81218'],
#  ['Jul 07 2023 01: +0', 1.299, '75819'],
#  ['Jul 08 2023 01: +0', 1.363, '68708'],
#  ['Jul 09 2023 01: +0', 1.405, '64394'],
#  ['Jul 10 2023 01: +0', 1.442, '58607'],
#  ['Jul 11 2023 01: +0', 1.501, '51475'],
#  ['Jul 12 2023 01: +0', 1.409, '92411'],
#  ['Jul 13 2023 01: +0', 1.341, '74228'],
#  ['Jul 14 2023 01: +0', 1.407, '70318'],
#  ['Jul 15 2023 01: +0', 1.456, '65696'],
#  ['Jul 16 2023 01: +0', 1.47, '59894'],
#  ['Jul 17 2023 01: +0', 1.483, '47992'],
#  ['Jul 18 2023 01: +0', 1.497, '49283'],
#  ['Jul 19 2023 01: +0', 1.394, '89891'],
#  ['Jul 20 2023 01: +0', 1.364, '77454'],
#  ['Jul 21 2023 01: +0', 1.41, '68592'],
#  ['Jul 22 2023 01: +0', 1.448, '60795'],
#  ['Jul 23 2023 01: +0', 1.46, '59250'],
#  ['Jul 24 2023 01: +0', 1.463, '51268'],
#  ['Jul 25 2023 01: +0', 1.478, '50248'],
#  ['Jul 26 2023 01: +0', 1.363, '91573'],
#  ['Jul 27 2023 01: +0', 1.328, '73708'],
#  ['Jul 28 2023 01: +0', 1.336, '68844'],
#  ['Jul 29 2023 01: +0', 1.376, '67574'],
#  ['Jul 30 2023 01: +0', 1.362, '58762'],
#  ['Jul 31 2023 01: +0', 1.379, '53986'],
#  ['Aug 01 2023 01: +0', 1.389, '53710'],
#  ['Aug 02 2023 01: +0', 1.275, '90025'],
#  ['Aug 03 2023 01: +0', 1.248, '77902'],
#  ['Aug 04 2023 01: +0', 1.263, '67528'],
#  ['Aug 05 2023 01: +0', 1.279, '65204'],
#  ['Aug 06 2023 01: +0', 1.263, '61415'],
#  ['Aug 07 2023 01: +0', 1.254, '53439'],
#  ['Aug 08 2023 01: +0', 1.245, '57835'],
#  ['Aug 09 2023 01: +0', 1.171, '100697'],
#  ['Aug 10 2023 01: +0', 1.121, '88102'],
#  ['Aug 11 2023 01: +0', 1.143, '85533'],
#  ['Aug 12 2023 01: +0', 1.189, '73720'],
#  ['Aug 13 2023 01: +0', 1.212, '62353'],
#  ['Aug 14 2023 01: +0', 1.229, '55289'],
#  ['Aug 15 2023 01: +0', 1.244, '57261'],
#  ['Aug 16 2023 01: +0', 1.122, '99080'],
#  ['Aug 17 2023 01: +0', 1.084, '85341'],
#  ['Aug 18 2023 01: +0', 1.101, '75990'],
#  ['Aug 19 2023 01: +0', 1.156, '71643'],
#  ['Aug 20 2023 01: +0', 1.156, '67068'],
#  ['Aug 21 2023 01: +0', 1.15, '61348'],
#  ['Aug 22 2023 01: +0', 1.169, '59754'],
#  ['Aug 23 2023 01: +0', 1.084, '99571'],
#  ['Aug 24 2023 01: +0', 1.058, '87106'],
#  ['Aug 25 2023 01: +0', 1.13, '78163'],
#  ['Aug 26 2023 01: +0', 1.157, '71261'],
#  ['Aug 27 2023 01: +0', 1.153, '68567'],
#  ['Aug 28 2023 01: +0', 1.175, '61699'],
#  ['Aug 29 2023 01: +0', 1.18, '55101'],
#  ['Aug 30 2023 01: +0', 1.082, '106285'],
#  ['Aug 31 2023 01: +0', 1.074, '87918'],
#  ['Sep 01 2023 01: +0', 1.119, '85512'],
#  ['Sep 02 2023 01: +0', 1.106, '89893'],
#  ['Sep 03 2023 01: +0', 1.114, '80135'],
#  ['Sep 04 2023 01: +0', 1.114, '80653'],
#  ['Sep 05 2023 01: +0', 1.152, '69559'],
#  ['Sep 06 2023 01: +0', 1.089, '116575'],
#  ['Sep 07 2023 01: +0', 1.066, '109879'],
#  ['Sep 08 2023 01: +0', 1.099, '92639'],
#  ['Sep 09 2023 01: +0', 1.117, '85591'],
#  ['Sep 10 2023 01: +0', 1.132, '83472'],
#  ['Sep 11 2023 01: +0', 1.174, '63225'],
#  ['Sep 12 2023 01: +0', 1.187, '60426'],
#  ['Sep 13 2023 01: +0', 1.118, '112952'],
#  ['Sep 14 2023 01: +0', 1.108, '98888'],
#  ['Sep 15 2023 01: +0', 1.149, '86930'],
#  ['Sep 16 2023 01: +0', 1.183, '94091'],
#  ['Sep 17 2023 01: +0', 1.181, '75913'],
#  ['Sep 18 2023 01: +0', 1.203, '58026'],
#  ['Sep 19 2023 01: +0', 1.219, '56438'],
#  ['Sep 20 2023 01: +0', 1.149, '111148'],
#  ['Sep 21 2023 01: +0', 1.17, '86088'],
#  ['Sep 22 2023 01: +0', 1.203, '79499'],
#  ['Sep 23 2023 01: +0', 1.212, '78003'],
#  ['Sep 24 2023 01: +0', 1.22, '69534'],
#  ['Sep 25 2023 01: +0', 1.256, '60051'],
#  ['Sep 26 2023 01: +0', 1.269, '54513'],
#  ['Sep 27 2023 01: +0', 1.233, '144396'],
#  ['Sep 28 2023 01: +0', 1.325, '176343'],
#  ['Sep 29 2023 01: +0', 1.366, '134945'],
#  ['Sep 30 2023 01: +0', 1.418, '126045'],
#  ['Oct 01 2023 01: +0', 1.441, '106921'],
#  ['Oct 02 2023 01: +0', 1.508, '87142'],
#  ['Oct 03 2023 01: +0', 1.54, '81369'],
#  ['Oct 04 2023 01: +0', 1.391, '130350'],
#  ['Oct 05 2023 01: +0', 1.32, '113362'],
#  ['Oct 06 2023 01: +0', 1.402, '105021'],
#  ['Oct 07 2023 01: +0', 1.466, '99667'],
#  ['Oct 08 2023 01: +0', 1.486, '87269'],
#  ['Oct 09 2023 01: +0', 1.495, '69147'],
#  ['Oct 10 2023 01: +0', 1.472, '68216'],
#  ['Oct 11 2023 01: +0', 1.376, '131449'],
#  ['Oct 12 2023 01: +0', 1.404, '109332'],
#  ['Oct 13 2023 01: +0', 1.429, '96337'],
#  ['Oct 14 2023 01: +0', 1.455, '97799'],
#  ['Oct 15 2023 01: +0', 1.481, '87021'],
#  ['Oct 16 2023 01: +0', 1.502, '66933'],
#  ['Oct 17 2023 01: +0', 1.52, '60293'],
#  ['Oct 18 2023 01: +0', 1.454, '122232'],
#  ['Oct 19 2023 01: +0', 1.43, '85478'],
#  ['Oct 19 2023 22: +0', 1.39, '4529'],
#  ['Oct 19 2023 23: +0', 1.396, '3678'],
#  ['Oct 20 2023 00: +0', 1.406, '2795'],
#  ['Oct 20 2023 01: +0', 1.41, '2801'],
#  ['Oct 20 2023 02: +0', 1.433, '3016'],
#  ['Oct 20 2023 03: +0', 1.46, '2822'],
#  ['Oct 20 2023 04: +0', 1.456, '2239'],
#  ['Oct 20 2023 05: +0', 1.47, '2583'],
#  ['Oct 20 2023 06: +0', 1.49, '2539'],
#  ['Oct 20 2023 07: +0', 1.49, '2451'],
#  ['Oct 20 2023 08: +0', 1.463, '2139'],
#  ['Oct 20 2023 09: +0', 1.452, '2279'],
#  ['Oct 20 2023 10: +0', 1.413, '1973'],
#  ['Oct 20 2023 11: +0', 1.427, '2882'],
#  ['Oct 20 2023 12: +0', 1.417, '3485'],
#  ['Oct 20 2023 13: +0', 1.398, '3497'],
#  ['Oct 20 2023 14: +0', 1.43, '4951'],
#  ['Oct 20 2023 15: +0', 1.391, '4548'],
#  ['Oct 20 2023 16: +0', 1.382, '4700'],
#  ['Oct 20 2023 17: +0', 1.385, '4957'],
#  ['Oct 20 2023 18: +0', 1.378, '4988'],
#  ['Oct 20 2023 19: +0', 1.386, '6101'],
#  ['Oct 20 2023 20: +0', 1.385, '6256'],
#  ['Oct 20 2023 21: +0', 1.395, '5804'],
#  ['Oct 20 2023 22: +0', 1.4, '5102'],
#  ['Oct 20 2023 23: +0', 1.4, '4014'],
#  ['Oct 21 2023 00: +0', 1.44, '3569'],
#  ['Oct 21 2023 01: +0', 1.47, '3194'],
#  ['Oct 21 2023 02: +0', 1.5, '3711'],
#  ['Oct 21 2023 03: +0', 1.51, '3213'],
#  ['Oct 21 2023 04: +0', 1.51, '3258'],
#  ['Oct 21 2023 05: +0', 1.524, '3504'],
#  ['Oct 21 2023 06: +0', 1.53, '2595'],
#  ['Oct 21 2023 07: +0', 1.49, '1932'],
#  ['Oct 21 2023 08: +0', 1.478, '2361'],
#  ['Oct 21 2023 09: +0', 1.43, '2287'],
#  ['Oct 21 2023 10: +0', 1.418, '2924'],
#  ['Oct 21 2023 11: +0', 1.39, '2902'],
#  ['Oct 21 2023 12: +0', 1.387, '3254'],
#  ['Oct 21 2023 13: +0', 1.384, '3277'],
#  ['Oct 21 2023 14: +0', 1.384, '3961'],
#  ['Oct 21 2023 15: +0', 1.406, '4314'],
#  ['Oct 21 2023 16: +0', 1.39, '3963'],
#  ['Oct 21 2023 17: +0', 1.39, '4419'],
#  ['Oct 21 2023 18: +0', 1.397, '4982'],
#  ['Oct 21 2023 19: +0', 1.41, '5021'],
#  ['Oct 21 2023 20: +0', 1.41, '4762'],
#  ['Oct 21 2023 21: +0', 1.397, '4452'],
#  ['Oct 21 2023 22: +0', 1.418, '4332'],
#  ['Oct 21 2023 23: +0', 1.418, '3544'],
#  ['Oct 22 2023 00: +0', 1.41, '2846'],
#  ['Oct 22 2023 01: +0', 1.47, '2895'],
#  ['Oct 22 2023 02: +0', 1.49, '2951'],
#  ['Oct 22 2023 03: +0', 1.483, '2693'],
#  ['Oct 22 2023 04: +0', 1.493, '3210'],
#  ['Oct 22 2023 05: +0', 1.49, '2609'],
#  ['Oct 22 2023 06: +0', 1.483, '2003'],
#  ['Oct 22 2023 07: +0', 1.495, '3084'],
#  ['Oct 22 2023 08: +0', 1.446, '1866'],
#  ['Oct 22 2023 09: +0', 1.42, '1977'],
#  ['Oct 22 2023 10: +0', 1.432, '3010'],
#  ['Oct 22 2023 11: +0', 1.413, '2774'],
#  ['Oct 22 2023 12: +0', 1.415, '3287'],
#  ['Oct 22 2023 13: +0', 1.397, '3363'],
#  ['Oct 22 2023 14: +0', 1.397, '3412'],
#  ['Oct 22 2023 15: +0', 1.4, '4071'],
#  ['Oct 22 2023 16: +0', 1.4, '3948'],
#  ['Oct 22 2023 17: +0', 1.406, '4111'],
#  ['Oct 22 2023 18: +0', 1.407, '3933'],
#  ['Oct 22 2023 19: +0', 1.4, '4241'],
#  ['Oct 22 2023 20: +0', 1.41, '4178'],
#  ['Oct 22 2023 21: +0', 1.42, '3916'],
#  ['Oct 22 2023 22: +0', 1.42, '3048'],
#  ['Oct 22 2023 23: +0', 1.448, '2781'],
#  ['Oct 23 2023 00: +0', 1.46, '2355'],
#  ['Oct 23 2023 01: +0', 1.468, '2435'],
#  ['Oct 23 2023 02: +0', 1.468, '2118'],
#  ['Oct 23 2023 03: +0', 1.47, '2436'],
#  ['Oct 23 2023 04: +0', 1.46, '1806'],
#  ['Oct 23 2023 05: +0', 1.46, '2010'],
#  ['Oct 23 2023 06: +0', 1.462, '1835'],
#  ['Oct 23 2023 07: +0', 1.46, '1668'],
#  ['Oct 23 2023 08: +0', 1.45, '1538'],
#  ['Oct 23 2023 09: +0', 1.44, '1638'],
#  ['Oct 23 2023 10: +0', 1.448, '1663'],
#  ['Oct 23 2023 11: +0', 1.421, '2055'],
#  ['Oct 23 2023 12: +0', 1.406, '2041'],
#  ['Oct 23 2023 13: +0', 1.422, '2714'],
#  ['Oct 23 2023 14: +0', 1.407, '2365'],
#  ['Oct 23 2023 15: +0', 1.428, '3150'],
#  ['Oct 23 2023 16: +0', 1.429, '3233'],
#  ['Oct 23 2023 17: +0', 1.432, '3352'],
#  ['Oct 23 2023 18: +0', 1.41, '3364'],
#  ['Oct 23 2023 19: +0', 1.429, '4099'],
#  ['Oct 23 2023 20: +0', 1.414, '3285'],
#  ['Oct 23 2023 21: +0', 1.419, '3173'],
#  ['Oct 23 2023 22: +0', 1.44, '2962'],
#  ['Oct 23 2023 23: +0', 1.45, '2450'],
#  ['Oct 24 2023 00: +0', 1.454, '2671'],
#  ['Oct 24 2023 01: +0', 1.46, '2262'],
#  ['Oct 24 2023 02: +0', 1.47, '2466'],
#  ['Oct 24 2023 03: +0', 1.49, '2181'],
#  ['Oct 24 2023 04: +0', 1.49, '2018'],
#  ['Oct 24 2023 05: +0', 1.49, '3091'],
#  ['Oct 24 2023 06: +0', 1.476, '1575'],
#  ['Oct 24 2023 07: +0', 1.484, '1757'],
#  ['Oct 24 2023 08: +0', 1.482, '1510'],
#  ['Oct 24 2023 09: +0', 1.486, '2297'],
#  ['Oct 24 2023 10: +0', 1.47, '2133'],
#  ['Oct 24 2023 11: +0', 1.446, '1621'],
#  ['Oct 24 2023 12: +0', 1.42, '1835'],
#  ['Oct 24 2023 13: +0', 1.419, '2054'],
#  ['Oct 24 2023 14: +0', 1.42, '2827'],
#  ['Oct 24 2023 15: +0', 1.419, '2525'],
#  ['Oct 24 2023 16: +0', 1.429, '2933'],
#  ['Oct 24 2023 17: +0', 1.421, '2794'],
#  ['Oct 24 2023 18: +0', 1.429, '3358'],
#  ['Oct 24 2023 19: +0', 1.42, '3240'],
#  ['Oct 24 2023 20: +0', 1.417, '2847'],
#  ['Oct 24 2023 21: +0', 1.412, '2501'],
#  ['Oct 24 2023 22: +0', 1.433, '2641'],
#  ['Oct 24 2023 23: +0', 1.464, '1977'],
#  ['Oct 25 2023 00: +0', 1.47, '2248'],
#  ['Oct 25 2023 01: +0', 1.46, '2336'],
#  ['Oct 25 2023 02: +0', 1.441, '3208'],
#  ['Oct 25 2023 03: +0', 1.44, '3511'],
#  ['Oct 25 2023 04: +0', 1.44, '3074'],
#  ['Oct 25 2023 05: +0', 1.43, '2843'],
#  ['Oct 25 2023 06: +0', 1.42, '2690'],
#  ['Oct 25 2023 07: +0', 1.41, '2325'],
#  ['Oct 25 2023 08: +0', 1.405, '2548'],
#  ['Oct 25 2023 09: +0', 1.4, '2762'],
#  ['Oct 25 2023 10: +0', 1.39, '3421'],
#  ['Oct 25 2023 11: +0', 1.379, '3647'],
#  ['Oct 25 2023 12: +0', 1.368, '4165'],
#  ['Oct 25 2023 13: +0', 1.376, '5272'],
#  ['Oct 25 2023 14: +0', 1.38, '5871'],
#  ['Oct 25 2023 15: +0', 1.369, '6440'],
#  ['Oct 25 2023 16: +0', 1.35, '6914'],
#  ['Oct 25 2023 17: +0', 1.35, '7239'],
#  ['Oct 25 2023 18: +0', 1.35, '8720'],
#  ['Oct 25 2023 19: +0', 1.35, '8682'],
#  ['Oct 25 2023 20: +0', 1.35, '8347'],
#  ['Oct 25 2023 21: +0', 1.35, '7790'],
#  ['Oct 25 2023 22: +0', 1.35, '6876'],
#  ['Oct 25 2023 23: +0', 1.363, '4495'],
#  ['Oct 26 2023 00: +0', 1.38, '3899'],
#  ['Oct 26 2023 01: +0', 1.38, '3055'],
#  ['Oct 26 2023 02: +0', 1.39, '3267'],
#  ['Oct 26 2023 03: +0', 1.382, '2391'],
#  ['Oct 26 2023 04: +0', 1.395, '2582'],
#  ['Oct 26 2023 05: +0', 1.393, '2382'],
#  ['Oct 26 2023 06: +0', 1.393, '2420'],
#  ['Oct 26 2023 07: +0', 1.38, '2058'],
#  ['Oct 26 2023 08: +0', 1.38, '2072'],
#  ['Oct 26 2023 09: +0', 1.367, '2162'],
#  ['Oct 26 2023 10: +0', 1.363, '2717'],
#  ['Oct 26 2023 11: +0', 1.353, '3002'],
#  ['Oct 26 2023 12: +0', 1.34, '3155'],
#  ['Oct 26 2023 13: +0', 1.342, '3918'],
#  ['Oct 26 2023 14: +0', 1.33, '4352'],
#  ['Oct 26 2023 15: +0', 1.32, '4565'],
#  ['Oct 26 2023 16: +0', 1.31, '4880'],
#  ['Oct 26 2023 17: +0', 1.3, '5213'],
#  ['Oct 26 2023 18: +0', 1.297, '5840'],
#  ['Oct 26 2023 19: +0', 1.297, '6464'],
#  ['Oct 26 2023 20: +0', 1.29, '6080'],
#  ['Oct 26 2023 21: +0', 1.29, '5387'],
#  ['Oct 26 2023 22: +0', 1.3, '5030'],
#  ['Oct 26 2023 23: +0', 1.3, '3748'],
#  ['Oct 27 2023 00: +0', 1.31, '3378'],
#  ['Oct 27 2023 01: +0', 1.33, '3100'],
#  ['Oct 27 2023 02: +0', 1.33, '2514'],
#  ['Oct 27 2023 03: +0', 1.349, '2811'],
#  ['Oct 27 2023 04: +0', 1.35, '2709'],
#  ['Oct 27 2023 05: +0', 1.35, '2349'],
#  ['Oct 27 2023 06: +0', 1.378, '2688'],
#  ['Oct 27 2023 07: +0', 1.36, '2352'],
#  ['Oct 27 2023 08: +0', 1.338, '1848'],
#  ['Oct 27 2023 09: +0', 1.32, '2131'],
#  ['Oct 27 2023 10: +0', 1.31, '2531'],
#  ['Oct 27 2023 11: +0', 1.314, '2749'],
#  ['Oct 27 2023 12: +0', 1.309, '2981'],
#  ['Oct 27 2023 13: +0', 1.305, '3466'],
#  ['Oct 27 2023 14: +0', 1.297, '3809'],
#  ['Oct 27 2023 15: +0', 1.304, '4857'],
#  ['Oct 27 2023 16: +0', 1.29, '4622'],
#  ['Oct 27 2023 17: +0', 1.297, '4808'],
#  ['Oct 27 2023 18: +0', 1.296, '4977'],
#  ['Oct 27 2023 19: +0', 1.286, '5487'],
#  ['Oct 27 2023 20: +0', 1.29, '5534'],
#  ['Oct 27 2023 21: +0', 1.3, '5430'],
#  ['Oct 27 2023 22: +0', 1.298, '4483'],
#  ['Oct 27 2023 23: +0', 1.301, '3617'],
#  ['Oct 28 2023 00: +0', 1.312, '3373'],
#  ['Oct 28 2023 01: +0', 1.33, '2898'],
#  ['Oct 28 2023 02: +0', 1.35, '2773'],
#  ['Oct 28 2023 03: +0', 1.365, '3149'],
#  ['Oct 28 2023 04: +0', 1.38, '2852'],
#  ['Oct 28 2023 05: +0', 1.365, '2808'],
#  ['Oct 28 2023 06: +0', 1.365, '2576'],
#  ['Oct 28 2023 07: +0', 1.35, '2666'],
#  ['Oct 28 2023 08: +0', 1.322, '2032'],
#  ['Oct 28 2023 09: +0', 1.312, '2803'],
#  ['Oct 28 2023 10: +0', 1.291, '2690'],
#  ['Oct 28 2023 11: +0', 1.29, '3082'],
#  ['Oct 28 2023 12: +0', 1.28, '3427'],
#  ['Oct 28 2023 13: +0', 1.28, '3556'],
#  ['Oct 28 2023 14: +0', 1.29, '3876'],
#  ['Oct 28 2023 15: +0', 1.291, '4088'],
#  ['Oct 28 2023 16: +0', 1.29, '4089'],
#  ['Oct 28 2023 17: +0', 1.28, '4325'],
#  ['Oct 28 2023 18: +0', 1.271, '4372'],
#  ['Oct 28 2023 19: +0', 1.27, '4323'],
#  ['Oct 28 2023 20: +0', 1.27, '4219'],
#  ['Oct 28 2023 21: +0', 1.267, '4214'],
#  ['Oct 28 2023 22: +0', 1.265, '3492'],
#  ['Oct 28 2023 23: +0', 1.27, '3145'],
#  ['Oct 29 2023 00: +0', 1.27, '2476'],
#  ['Oct 29 2023 01: +0', 1.31, '2652'],
#  ['Oct 29 2023 02: +0', 1.312, '2086'],
#  ['Oct 29 2023 03: +0', 1.33, '2479'],
#  ['Oct 29 2023 04: +0', 1.32, '2399'],
#  ['Oct 29 2023 05: +0', 1.3, '2386'],
#  ['Oct 29 2023 06: +0', 1.28, '1757'],
#  ['Oct 29 2023 07: +0', 1.28, '2395'],
#  ['Oct 29 2023 08: +0', 1.27, '1959'],
#  ['Oct 29 2023 09: +0', 1.26, '1828'],
#  ['Oct 29 2023 10: +0', 1.243, '2272'],
#  ['Oct 29 2023 11: +0', 1.24, '2653'],
#  ['Oct 29 2023 12: +0', 1.238, '3088'],
#  ['Oct 29 2023 13: +0', 1.23, '2990'],
#  ['Oct 29 2023 14: +0', 1.238, '4076'],
#  ['Oct 29 2023 15: +0', 1.227, '3494'],
#  ['Oct 29 2023 16: +0', 1.227, '3686'],
#  ['Oct 29 2023 17: +0', 1.23, '3635'],
#  ['Oct 29 2023 18: +0', 1.231, '3798'],
#  ['Oct 29 2023 19: +0', 1.217, '4782'],
#  ['Oct 29 2023 20: +0', 1.225, '3837'],
#  ['Oct 29 2023 21: +0', 1.227, '3852'],
#  ['Oct 29 2023 22: +0', 1.228, '3213'],
#  ['Oct 29 2023 23: +0', 1.24, '2853'],
#  ['Oct 30 2023 00: +0', 1.243, '2488'],
#  ['Oct 30 2023 01: +0', 1.259, '2322'],
#  ['Oct 30 2023 02: +0', 1.26, '2404'],
#  ['Oct 30 2023 03: +0', 1.264, '2180'],
#  ['Oct 30 2023 04: +0', 1.265, '1964'],
#  ['Oct 30 2023 05: +0', 1.264, '1760'],
#  ['Oct 30 2023 06: +0', 1.26, '1895'],
#  ['Oct 30 2023 07: +0', 1.235, '1130'],
#  ['Oct 30 2023 08: +0', 1.214, '2097'],
#  ['Oct 30 2023 09: +0', 1.208, '1891'],
#  ['Oct 30 2023 10: +0', 1.225, '2212'],
#  ['Oct 30 2023 11: +0', 1.217, '2026'],
#  ['Oct 30 2023 12: +0', 1.214, '2044'],
#  ['Oct 30 2023 13: +0', 1.217, '2210'],
#  ['Oct 30 2023 14: +0', 1.21, '2342'],
#  ['Oct 30 2023 15: +0', 1.214, '2851'],
#  ['Oct 30 2023 16: +0', 1.21, '2984'],
#  ['Oct 30 2023 17: +0', 1.21, '3190'],
#  ['Oct 30 2023 18: +0', 1.203, '3370'],
#  ['Oct 30 2023 19: +0', 1.206, '3369'],
#  ['Oct 30 2023 20: +0', 1.206, '3375'],
#  ['Oct 30 2023 21: +0', 1.203, '3050'],
#  ['Oct 30 2023 22: +0', 1.22, '3178'],
#  ['Oct 30 2023 23: +0', 1.23, '2957'],
#  ['Oct 31 2023 00: +0', 1.23, '2655'],
#  ['Oct 31 2023 01: +0', 1.251, '2324'],
#  ['Oct 31 2023 02: +0', 1.23, '1930'],
#  ['Oct 31 2023 03: +0', 1.23, '2399'],
#  ['Oct 31 2023 04: +0', 1.23, '2389'],
#  ['Oct 31 2023 05: +0', 1.24, '2301'],
#  ['Oct 31 2023 06: +0', 1.24, '1949'],
#  ['Oct 31 2023 07: +0', 1.223, '1152'],
#  ['Oct 31 2023 08: +0', 1.22, '1626'],
#  ['Oct 31 2023 09: +0', 1.26, '2363'],
#  ['Oct 31 2023 10: +0', 1.219, '1557'],
#  ['Oct 31 2023 11: +0', 1.23, '2047'],
#  ['Oct 31 2023 12: +0', 1.217, '1992'],
#  ['Oct 31 2023 13: +0', 1.218, '2695'],
#  ['Oct 31 2023 14: +0', 1.213, '2550'],
#  ['Oct 31 2023 15: +0', 1.219, '2590'],
#  ['Oct 31 2023 16: +0', 1.2, '2538'],
#  ['Oct 31 2023 17: +0', 1.21, '3700'],
#  ['Oct 31 2023 18: +0', 1.21, '2917'],
#  ['Oct 31 2023 19: +0', 1.201, '2891'],
#  ['Oct 31 2023 20: +0', 1.187, '3097'],
#  ['Oct 31 2023 21: +0', 1.2, '3586'],
#  ['Oct 31 2023 22: +0', 1.2, '2977'],
#  ['Oct 31 2023 23: +0', 1.2, '2780'],
#  ['Nov 01 2023 00: +0', 1.2, '2616'],
#  ['Nov 01 2023 01: +0', 1.214, '2354'],
#  ['Nov 01 2023 02: +0', 1.19, '2893'],
#  ['Nov 01 2023 03: +0', 1.19, '3233'],
#  ['Nov 01 2023 04: +0', 1.19, '2839'],
#  ['Nov 01 2023 05: +0', 1.19, '2418'],
#  ['Nov 01 2023 06: +0', 1.195, '2618'],
#  ['Nov 01 2023 07: +0', 1.19, '2103'],
#  ['Nov 01 2023 08: +0', 1.187, '2671'],
#  ['Nov 01 2023 09: +0', 1.187, '2962'],
#  ['Nov 01 2023 10: +0', 1.19, '3946'],
#  ['Nov 01 2023 11: +0', 1.18, '4198'],
#  ['Nov 01 2023 12: +0', 1.17, '4868'],
#  ['Nov 01 2023 13: +0', 1.17, '5425'],
#  ['Nov 01 2023 14: +0', 1.16, '5962'],
#  ['Nov 01 2023 15: +0', 1.15, '6570'],
#  ['Nov 01 2023 16: +0', 1.145, '6931'],
#  ['Nov 01 2023 17: +0', 1.12, '7932'],
#  ['Nov 01 2023 18: +0', 1.12, '8189'],
#  ['Nov 01 2023 19: +0', 1.12, '8783'],
#  ['Nov 01 2023 20: +0', 1.12, '9316'],
#  ['Nov 01 2023 21: +0', 1.12, '8698'],
#  ['Nov 01 2023 22: +0', 1.11, '7255'],
#  ['Nov 01 2023 23: +0', 1.11, '5319'],
#  ['Nov 02 2023 00: +0', 1.11, '4227'],
#  ['Nov 02 2023 01: +0', 1.127, '3980'],
#  ['Nov 02 2023 02: +0', 1.137, '3278'],
#  ['Nov 02 2023 03: +0', 1.15, '2879'],
#  ['Nov 02 2023 04: +0', 1.15, '2714'],
#  ['Nov 02 2023 05: +0', 1.159, '2981'],
#  ['Nov 02 2023 06: +0', 1.15, '2191'],
#  ['Nov 02 2023 07: +0', 1.15, '1889'],
#  ['Nov 02 2023 08: +0', 1.15, '2332'],
#  ['Nov 02 2023 09: +0', 1.137, '2475'],
#  ['Nov 02 2023 10: +0', 1.12, '2944'],
#  ['Nov 02 2023 11: +0', 1.13, '3748'],
#  ['Nov 02 2023 12: +0', 1.12, '3678'],
#  ['Nov 02 2023 13: +0', 1.12, '4307'],
#  ['Nov 02 2023 14: +0', 1.12, '4731'],
#  ['Nov 02 2023 15: +0', 1.11, '5430'],
#  ['Nov 02 2023 16: +0', 1.1, '5385'],
#  ['Nov 02 2023 17: +0', 1.1, '6451'],
#  ['Nov 02 2023 18: +0', 1.1, '6533'],
#  ['Nov 02 2023 19: +0', 1.095, '6580'],
#  ['Nov 02 2023 20: +0', 1.07, '6194'],
#  ['Nov 02 2023 21: +0', 1.075, '6347'],
#  ['Nov 02 2023 22: +0', 1.08, '5060'],
#  ['Nov 02 2023 23: +0', 1.09, '4647'],
#  ['Nov 03 2023 00: +0', 1.102, '4042'],
#  ['Nov 03 2023 01: +0', 1.11, '3164'],
#  ['Nov 03 2023 02: +0', 1.124, '3344'],
#  ['Nov 03 2023 03: +0', 1.157, '2801'],
#  ['Nov 03 2023 04: +0', 1.17, '2671'],
#  ['Nov 03 2023 05: +0', 1.18, '2040'],
#  ['Nov 03 2023 06: +0', 1.181, '2017'],
#  ['Nov 03 2023 07: +0', 1.181, '2021'],
#  ['Nov 03 2023 08: +0', 1.16, '1796'],
#  ['Nov 03 2023 09: +0', 1.16, '2005'],
#  ['Nov 03 2023 10: +0', 1.131, '2151'],
#  ['Nov 03 2023 11: +0', 1.125, '2505'],
#  ['Nov 03 2023 12: +0', 1.117, '2787'],
#  ['Nov 03 2023 13: +0', 1.1, '3162'],
#  ['Nov 03 2023 14: +0', 1.096, '3580'],
#  ['Nov 03 2023 15: +0', 1.096, '4166'],
#  ['Nov 03 2023 16: +0', 1.11, '4402'],
#  ['Nov 03 2023 17: +0', 1.101, '4481'],
#  ['Nov 03 2023 18: +0', 1.117, '5112'],
#  ['Nov 03 2023 19: +0', 1.117, '5197'],
#  ['Nov 03 2023 20: +0', 1.133, '5280'],
#  ['Nov 03 2023 21: +0', 1.12, '5249'],
#  ['Nov 03 2023 22: +0', 1.132, '4761'],
#  ['Nov 03 2023 23: +0', 1.149, '4053'],
#  ['Nov 04 2023 00: +0', 1.17, '3628'],
#  ['Nov 04 2023 01: +0', 1.2, '3518'],
#  ['Nov 04 2023 02: +0', 1.207, '3487'],
#  ['Nov 04 2023 03: +0', 1.21, '2808'],
#  ['Nov 04 2023 04: +0', 1.22, '3319'],
#  ['Nov 04 2023 05: +0', 1.22, '2958'],
#  ['Nov 04 2023 06: +0', 1.22, '2536'],
#  ['Nov 04 2023 07: +0', 1.21, '1811'],
#  ['Nov 04 2023 08: +0', 1.18, '1927'],
#  ['Nov 04 2023 09: +0', 1.186, '2495'],
#  ['Nov 04 2023 10: +0', 1.149, '2577'],
#  ['Nov 04 2023 11: +0', 1.135, '2461'],
#  ['Nov 04 2023 12: +0', 1.124, '2886'],
#  ['Nov 04 2023 13: +0', 1.115, '3414'],
#  ['Nov 04 2023 14: +0', 1.16, '4074'],
#  ['Nov 04 2023 15: +0', 1.131, '3508'],
#  ['Nov 04 2023 16: +0', 1.135, '3582'],
#  ['Nov 04 2023 17: +0', 1.134, '3902'],
#  ['Nov 04 2023 18: +0', 1.143, '4140'],
#  ['Nov 04 2023 19: +0', 1.155, '4317'],
#  ['Nov 04 2023 20: +0', 1.131, '4235'],
#  ['Nov 04 2023 21: +0', 1.146, '3772'],
#  ['Nov 04 2023 22: +0', 1.157, '3608'],
#  ['Nov 04 2023 23: +0', 1.171, '3604'],
#  ['Nov 05 2023 00: +0', 1.199, '3059'],
#  ['Nov 05 2023 01: +0', 1.22, '2868'],
#  ['Nov 05 2023 02: +0', 1.212, '2021'],
#  ['Nov 05 2023 03: +0', 1.22, '2107'],
#  ['Nov 05 2023 04: +0', 1.22, '2704'],
#  ['Nov 05 2023 05: +0', 1.22, '2316'],
#  ['Nov 05 2023 06: +0', 1.23, '2574'],
#  ['Nov 05 2023 07: +0', 1.23, '2047'],
#  ['Nov 05 2023 08: +0', 1.199, '1718'],
#  ['Nov 05 2023 09: +0', 1.195, '1955'],
#  ['Nov 05 2023 10: +0', 1.176, '1997'],
#  ['Nov 05 2023 11: +0', 1.15, '2116'],
#  ['Nov 05 2023 12: +0', 1.15, '2560'],
#  ['Nov 05 2023 13: +0', 1.143, '2762'],
#  ['Nov 05 2023 14: +0', 1.149, '3348'],
#  ['Nov 05 2023 15: +0', 1.146, '3492'],
#  ['Nov 05 2023 16: +0', 1.158, '3528'],
#  ['Nov 05 2023 17: +0', 1.15, '3425'],
#  ['Nov 05 2023 18: +0', 1.157, '3690'],
#  ['Nov 05 2023 19: +0', 1.157, '3450'],
#  ['Nov 05 2023 20: +0', 1.157, '3658'],
#  ['Nov 05 2023 21: +0', 1.158, '3469'],
#  ['Nov 05 2023 22: +0', 1.158, '2766'],
#  ['Nov 05 2023 23: +0', 1.18, '2854'],
#  ['Nov 06 2023 00: +0', 1.191, '2210'],
#  ['Nov 06 2023 01: +0', 1.21, '2180'],
#  ['Nov 06 2023 02: +0', 1.2, '1292'],
#  ['Nov 06 2023 03: +0', 1.22, '2348'],
#  ['Nov 06 2023 04: +0', 1.22, '2341'],
#  ['Nov 06 2023 05: +0', 1.212, '1861'],
#  ['Nov 06 2023 06: +0', 1.21, '1298'],
#  ['Nov 06 2023 07: +0', 1.23, '1648'],
#  ['Nov 06 2023 08: +0', 1.22, '1411'],
#  ['Nov 06 2023 09: +0', 1.204, '1627'],
#  ['Nov 06 2023 10: +0', 1.199, '1698'],
#  ['Nov 06 2023 11: +0', 1.178, '1295'],
#  ['Nov 06 2023 12: +0', 1.189, '2100'],
#  ['Nov 06 2023 13: +0', 1.176, '2114'],
#  ['Nov 06 2023 14: +0', 1.164, '2348'],
#  ['Nov 06 2023 15: +0', 1.17, '2936'],
#  ['Nov 06 2023 16: +0', 1.186, '3070'],
#  ['Nov 06 2023 17: +0', 1.22, '3686'],
#  ['Nov 06 2023 18: +0', 1.195, '2814'],
#  ['Nov 06 2023 19: +0', 1.227, '3807'],
#  ['Nov 06 2023 20: +0', 1.23, '4107'],
#  ['Nov 06 2023 21: +0', 1.22, '2922'],
#  ['Nov 06 2023 22: +0', 1.228, '2963'],
#  ['Nov 06 2023 23: +0', 1.23, '2692'],
#  ['Nov 07 2023 00: +0', 1.231, '2062'],
#  ['Nov 07 2023 01: +0', 1.24, '1838'],
#  ['Nov 07 2023 02: +0', 1.256, '2297'],
#  ['Nov 07 2023 03: +0', 1.246, '1643'],
#  ['Nov 07 2023 04: +0', 1.26, '2247'],
#  ['Nov 07 2023 05: +0', 1.268, '1632'],
#  ['Nov 07 2023 06: +0', 1.278, '2413'],
#  ['Nov 07 2023 07: +0', 1.28, '1429'],
#  ['Nov 07 2023 08: +0', 1.26, '1343'],
#  ['Nov 07 2023 09: +0', 1.27, '1810'],
#  ['Nov 07 2023 10: +0', 1.235, '1282'],
#  ['Nov 07 2023 11: +0', 1.245, '1432'],
#  ['Nov 07 2023 12: +0', 1.259, '1815'],
#  ['Nov 07 2023 13: +0', 1.242, '1978'],
#  ['Nov 07 2023 14: +0', 1.248, '2287'],
#  ['Nov 07 2023 15: +0', 1.232, '2005'],
#  ['Nov 07 2023 16: +0', 1.23, '2238'],
#  ['Nov 07 2023 17: +0', 1.24, '2479'],
#  ['Nov 07 2023 18: +0', 1.23, '3064'],
#  ['Nov 07 2023 19: +0', 1.236, '3012'],
#  ['Nov 07 2023 20: +0', 1.235, '2656'],
#  ['Nov 07 2023 21: +0', 1.23, '2674'],
#  ['Nov 07 2023 22: +0', 1.23, '2336'],
#  ['Nov 07 2023 23: +0', 1.24, '2149'],
#  ['Nov 08 2023 00: +0', 1.269, '1678'],
#  ['Nov 08 2023 01: +0', 1.278, '1901'],
#  ['Nov 08 2023 02: +0', 1.28, '1947'],
#  ['Nov 08 2023 03: +0', 1.23, '2591'],
#  ['Nov 08 2023 04: +0', 1.23, '2828'],
#  ['Nov 08 2023 05: +0', 1.22, '2256'],
#  ['Nov 08 2023 06: +0', 1.223, '2019'],
#  ['Nov 08 2023 07: +0', 1.23, '2206'],
#  ['Nov 08 2023 08: +0', 1.234, '2914'],
#  ['Nov 08 2023 09: +0', 1.21, '2753'],
#  ['Nov 08 2023 10: +0', 1.21, '3022'],
#  ['Nov 08 2023 11: +0', 1.21, '3450'],
#  ['Nov 08 2023 12: +0', 1.21, '4374'],
#  ['Nov 08 2023 13: +0', 1.2, '4132'],
#  ['Nov 08 2023 14: +0', 1.18, '4598'],
#  ['Nov 08 2023 15: +0', 1.17, '5340'],
#  ['Nov 08 2023 16: +0', 1.17, '5946'],
#  ['Nov 08 2023 17: +0', 1.16, '6243'],
#  ['Nov 08 2023 18: +0', 1.12, '6420'],
#  ['Nov 08 2023 19: +0', 1.12, '7412'],
#  ['Nov 08 2023 20: +0', 1.12, '7620'],
#  ['Nov 08 2023 21: +0', 1.12, '6783'],
#  ['Nov 08 2023 22: +0', 1.12, '5587'],
#  ['Nov 08 2023 23: +0', 1.12, '4383'],
#  ['Nov 09 2023 00: +0', 1.126, '3766'],
#  ['Nov 09 2023 01: +0', 1.164, '3616'],
#  ['Nov 09 2023 02: +0', 1.178, '2974'],
#  ['Nov 09 2023 03: +0', 1.18, '2505'],
#  ['Nov 09 2023 04: +0', 1.188, '2455'],
#  ['Nov 09 2023 05: +0', 1.19, '2237'],
#  ['Nov 09 2023 06: +0', 1.203, '2218'],
#  ['Nov 09 2023 07: +0', 1.19, '1732'],
#  ['Nov 09 2023 08: +0', 1.164, '1646'],
#  ['Nov 09 2023 09: +0', 1.16, '1970'],
#  ['Nov 09 2023 10: +0', 1.156, '2358'],
#  ['Nov 09 2023 11: +0', 1.142, '2993'],
#  ['Nov 09 2023 12: +0', 1.142, '3310'],
#  ['Nov 09 2023 13: +0', 1.12, '3496'],
#  ['Nov 09 2023 14: +0', 1.11, '4174'],
#  ['Nov 09 2023 15: +0', 1.11, '4420'],
#  ['Nov 09 2023 16: +0', 1.116, '4822'],
#  ['Nov 09 2023 17: +0', 1.102, '5422'],
#  ['Nov 09 2023 18: +0', 1.1, '5461'],
#  ['Nov 09 2023 19: +0', 1.1, '5636'],
#  ['Nov 09 2023 20: +0', 1.1, '5543'],
#  ['Nov 09 2023 21: +0', 1.102, '5200'],
#  ['Nov 09 2023 22: +0', 1.098, '4409'],
#  ['Nov 09 2023 23: +0', 1.095, '3572'],
#  ['Nov 10 2023 00: +0', 1.109, '2938'],
#  ['Nov 10 2023 01: +0', 1.141, '2730'],
#  ['Nov 10 2023 02: +0', 1.17, '2709'],
#  ['Nov 10 2023 03: +0', 1.183, '2596'],
#  ['Nov 10 2023 04: +0', 1.18, '1933'],
#  ['Nov 10 2023 05: +0', 1.192, '1796'],
#  ['Nov 10 2023 06: +0', 1.21, '1972'],
#  ['Nov 10 2023 07: +0', 1.19, '1733'],
#  ['Nov 10 2023 08: +0', 1.19, '2071'],
#  ['Nov 10 2023 09: +0', 1.135, '1606'],
#  ['Nov 10 2023 10: +0', 1.124, '2440'],
#  ['Nov 10 2023 11: +0', 1.167, '3230'],
#  ['Nov 10 2023 12: +0', 1.124, '2810'],
#  ['Nov 10 2023 13: +0', 1.122, '3105'],
#  ['Nov 10 2023 14: +0', 1.109, '3779'],
#  ['Nov 10 2023 15: +0', 1.11, '3555'],
#  ['Nov 10 2023 16: +0', 1.104, '3898'],
#  ['Nov 10 2023 17: +0', 1.103, '4972'],
#  ['Nov 10 2023 18: +0', 1.103, '5069'],
#  ['Nov 10 2023 19: +0', 1.093, '4832'],
#  ['Nov 10 2023 20: +0', 1.093, '5074'],
#  ['Nov 10 2023 21: +0', 1.099, '5104'],
#  ['Nov 10 2023 22: +0', 1.1, '4635'],
#  ['Nov 10 2023 23: +0', 1.106, '4016'],
#  ['Nov 11 2023 00: +0', 1.12, '3302'],
#  ['Nov 11 2023 01: +0', 1.15, '2814'],
#  ['Nov 11 2023 02: +0', 1.196, '3039'],
#  ['Nov 11 2023 03: +0', 1.21, '2674'],
#  ['Nov 11 2023 04: +0', 1.229, '2914'],
#  ['Nov 11 2023 05: +0', 1.226, '3063'],
#  ['Nov 11 2023 06: +0', 1.226, '2378'],
#  ['Nov 11 2023 07: +0', 1.21, '2100'],
#  ['Nov 11 2023 08: +0', 1.2, '2428'],
#  ['Nov 11 2023 09: +0', 1.132, '1932'],
#  ['Nov 11 2023 10: +0', 1.106, '2652'],
#  ['Nov 11 2023 11: +0', 1.097, '2694'],
#  ['Nov 11 2023 12: +0', 1.09, '2764'],
#  ['Nov 11 2023 13: +0', 1.092, '3113'],
#  ['Nov 11 2023 14: +0', 1.1, '3654'],
#  ['Nov 11 2023 15: +0', 1.087, '3671'],
#  ['Nov 11 2023 16: +0', 1.09, '4149'],
#  ['Nov 11 2023 17: +0', 1.09, '3854'],
#  ['Nov 11 2023 18: +0', 1.089, '4011'],
#  ['Nov 11 2023 19: +0', 1.087, '4297'],
#  ['Nov 11 2023 20: +0', 1.08, '3736'],
#  ['Nov 11 2023 21: +0', 1.079, '4180'],
#  ['Nov 11 2023 22: +0', 1.079, '3893'],
#  ['Nov 11 2023 23: +0', 1.077, '3255'],
#  ['Nov 12 2023 00: +0', 1.09, '2627'],
#  ['Nov 12 2023 01: +0', 1.1, '2213'],
#  ['Nov 12 2023 02: +0', 1.12, '2009'],
#  ['Nov 12 2023 03: +0', 1.162, '2277'],
#  ['Nov 12 2023 04: +0', 1.144, '1932'],
#  ['Nov 12 2023 05: +0', 1.16, '2135'],
#  ['Nov 12 2023 06: +0', 1.15, '2303'],
#  ['Nov 12 2023 07: +0', 1.11, '1605'],
#  ['Nov 12 2023 08: +0', 1.12, '2140'],
#  ['Nov 12 2023 09: +0', 1.09, '2189'],
#  ['Nov 12 2023 10: +0', 1.068, '2022'],
#  ['Nov 12 2023 11: +0', 1.063, '2386'],
#  ['Nov 12 2023 12: +0', 1.05, '2680'],
#  ['Nov 12 2023 13: +0', 1.047, '2954'],
#  ['Nov 12 2023 14: +0', 1.04, '2780'],
#  ['Nov 12 2023 15: +0', 1.036, '3088'],
#  ['Nov 12 2023 16: +0', 1.026, '3197'],
#  ['Nov 12 2023 17: +0', 1.037, '3484'],
#  ['Nov 12 2023 18: +0', 1.026, '3170'],
#  ['Nov 12 2023 19: +0', 1.03, '3440'],
#  ['Nov 12 2023 20: +0', 1.03, '3160'],
#  ['Nov 12 2023 21: +0', 1.039, '3359'],
#  ['Nov 12 2023 22: +0', 1.04, '2819'],
#  ['Nov 12 2023 23: +0', 1.036, '2365'],
#  ['Nov 13 2023 00: +0', 1.052, '2081'],
#  ['Nov 13 2023 01: +0', 1.05, '1723'],
#  ['Nov 13 2023 02: +0', 1.068, '2565'],
#  ['Nov 13 2023 03: +0', 1.06, '1995'],
#  ['Nov 13 2023 04: +0', 1.06, '1530'],
#  ['Nov 13 2023 05: +0', 1.05, '1285'],
#  ['Nov 13 2023 06: +0', 1.05, '1272'],
#  ['Nov 13 2023 07: +0', 1.05, '1159'],
#  ['Nov 13 2023 08: +0', 1.04, '1512'],
#  ['Nov 13 2023 09: +0', 1.013, '1073'],
#  ['Nov 13 2023 10: +0', 1.015, '1355'],
#  ['Nov 13 2023 11: +0', 1.024, '1791'],
#  ['Nov 13 2023 12: +0', 1.004, '1510'],
#  ['Nov 13 2023 13: +0', 1.014, '2042'],
#  ['Nov 13 2023 14: +0', 1.015, '2181'],
#  ['Nov 13 2023 15: +0', 1.015, '2651'],
#  ['Nov 13 2023 16: +0', 1.01, '2537'],
#  ['Nov 13 2023 17: +0', 1.015, '3157'],
#  ['Nov 13 2023 18: +0', 1.015, '2590'],
#  ['Nov 13 2023 19: +0', 1, '2948'],
#  ['Nov 13 2023 20: +0', 0.993, '2789'],
#  ['Nov 13 2023 21: +0', 0.992, '2757'],
#  ['Nov 13 2023 22: +0', 0.996, '2542'],
#  ['Nov 13 2023 23: +0', 1, '1914'],
#  ['Nov 14 2023 00: +0', 1.013, '1880'],
#  ['Nov 14 2023 01: +0', 1, '1409'],
#  ['Nov 14 2023 02: +0', 1.019, '1511'],
#  ['Nov 14 2023 03: +0', 1.01, '1611'],
#  ['Nov 14 2023 04: +0', 1.01, '1631'],
#  ['Nov 14 2023 05: +0', 1.023, '2117'],
#  ['Nov 14 2023 06: +0', 1.04, '2571'],
#  ['Nov 14 2023 07: +0', 1.03, '1951'],
#  ['Nov 14 2023 08: +0', 1.03, '1498'],
#  ['Nov 14 2023 09: +0', 1.028, '2033'],
#  ['Nov 14 2023 10: +0', 0.999, '1444'],
#  ['Nov 14 2023 11: +0', 0.99, '2220'],
#  ['Nov 14 2023 12: +0', 0.988, '1857'],
#  ['Nov 14 2023 13: +0', 0.96, '1556'],
#  ['Nov 14 2023 14: +0', 0.96, '2021'],
#  ['Nov 14 2023 15: +0', 0.969, '2929'],
#  ['Nov 14 2023 16: +0', 0.958, '2620'],
#  ['Nov 14 2023 17: +0', 0.961, '3073'],
#  ['Nov 14 2023 18: +0', 0.949, '2711'],
#  ['Nov 14 2023 19: +0', 0.945, '2963'],
#  ['Nov 14 2023 20: +0', 0.949, '2970'],
#  ['Nov 14 2023 21: +0', 0.953, '3111'],
#  ['Nov 14 2023 22: +0', 0.97, '3072'],
#  ['Nov 14 2023 23: +0', 0.97, '2768'],
#  ['Nov 15 2023 00: +0', 0.988, '2109'],
#  ['Nov 15 2023 01: +0', 0.997, '2149'],
#  ['Nov 15 2023 02: +0', 1, '2194'],
#  ['Nov 15 2023 03: +0', 0.951, '2804'],
#  ['Nov 15 2023 04: +0', 0.95, '3383'],
#  ['Nov 15 2023 05: +0', 0.938, '2664'],
#  ['Nov 15 2023 06: +0', 0.937, '2985'],
#  ['Nov 15 2023 07: +0', 0.92, '2416'],
#  ['Nov 15 2023 08: +0', 0.918, '2695'],
#  ['Nov 15 2023 09: +0', 0.89, '2958'],
#  ['Nov 15 2023 10: +0', 0.882, '3526'],
#  ['Nov 15 2023 11: +0', 0.872, '3940'],
#  ['Nov 15 2023 12: +0', 0.872, '4644'],
#  ['Nov 15 2023 13: +0', 0.871, '4681'],
#  ['Nov 15 2023 14: +0', 0.85, '6296'],
#  ['Nov 15 2023 15: +0', 0.839, '5223'],
#  ['Nov 15 2023 16: +0', 0.823, '5901'],
#  ['Nov 15 2023 17: +0', 0.82, '6284'],
#  ['Nov 15 2023 18: +0', 0.82, '7567'],
#  ['Nov 15 2023 19: +0', 0.82, '7207'],
#  ['Nov 15 2023 20: +0', 0.814, '7154'],
#  ['Nov 15 2023 21: +0', 0.8, '6056'],
#  ['Nov 15 2023 22: +0', 0.8, '5250'],
#  ['Nov 15 2023 23: +0', 0.8, '4169'],
#  ['Nov 16 2023 00: +0', 0.803, '3701'],
#  ['Nov 16 2023 01: +0', 0.805, '2996'],
#  ['Nov 16 2023 02: +0', 0.808, '2384'],
#  ['Nov 16 2023 03: +0', 0.81, '2459'],
#  ['Nov 16 2023 04: +0', 0.82, '2558'],
#  ['Nov 16 2023 05: +0', 0.825, '2213'],
#  ['Nov 16 2023 06: +0', 0.835, '2225'],
#  ['Nov 16 2023 07: +0', 0.832, '2094'],
#  ['Nov 16 2023 08: +0', 0.81, '1906'],
#  ['Nov 16 2023 09: +0', 0.803, '2267'],
#  ['Nov 16 2023 10: +0', 0.792, '3362'],
#  ['Nov 16 2023 11: +0', 0.78, '3296'],
#  ['Nov 16 2023 12: +0', 0.78, '2718'],
#  ['Nov 16 2023 13: +0', 0.786, '3356'],
#  ['Nov 16 2023 14: +0', 0.78, '3396'],
#  ['Nov 16 2023 15: +0', 0.77, '3986'],
#  ['Nov 16 2023 16: +0', 0.78, '4452'],
#  ['Nov 16 2023 17: +0', 0.792, '4973'],
#  ['Nov 16 2023 18: +0', 0.791, '5298'],
#  ['Nov 16 2023 19: +0', 0.78, '5060'],
#  ['Nov 16 2023 20: +0', 0.77, '5242'],
#  ['Nov 16 2023 21: +0', 0.763, '4449'],
#  ['Nov 16 2023 22: +0', 0.77, '4295'],
#  ['Nov 16 2023 23: +0', 0.77, '3341'],
#  ['Nov 17 2023 00: +0', 0.78, '3174'],
#  ['Nov 17 2023 01: +0', 0.807, '2759'],
#  ['Nov 17 2023 02: +0', 0.81, '2411'],
#  ['Nov 17 2023 03: +0', 0.82, '2734'],
#  ['Nov 17 2023 04: +0', 0.824, '2553'],
#  ['Nov 17 2023 05: +0', 0.83, '1972'],
#  ['Nov 17 2023 06: +0', 0.83, '2010'],
#  ['Nov 17 2023 07: +0', 0.831, '2292'],
#  ['Nov 17 2023 08: +0', 0.82, '2163'],
#  ['Nov 17 2023 09: +0', 0.81, '1805'],
#  ['Nov 17 2023 10: +0', 0.8, '1987'],
#  ['Nov 17 2023 11: +0', 0.81, '2643'],
#  ['Nov 17 2023 12: +0', 0.785, '2424'],
#  ['Nov 17 2023 13: +0', 0.786, '2650'],
#  ['Nov 17 2023 14: +0', 0.793, '3477'],
#  ['Nov 17 2023 15: +0', 0.786, '3183'],
#  ['Nov 17 2023 16: +0', 0.779, '3558'],
#  ['Nov 17 2023 17: +0', 0.78, '4048'],
#  ['Nov 17 2023 18: +0', 0.789, '4020'],
#  ['Nov 17 2023 19: +0', 0.786, '3960'],
#  ['Nov 17 2023 20: +0', 0.78, '4216'],
#  ['Nov 17 2023 21: +0', 0.783, '4423'],
#  ['Nov 17 2023 22: +0', 0.793, '4444'],
#  ['Nov 17 2023 23: +0', 0.79, '3384'],
#  ['Nov 18 2023 00: +0', 0.793, '2670'],
#  ['Nov 18 2023 01: +0', 0.83, '3260'],
#  ['Nov 18 2023 02: +0', 0.84, '2905'],
#  ['Nov 18 2023 03: +0', 0.848, '3209'],
#  ['Nov 18 2023 04: +0', 0.84, '2835'],
#  ['Nov 18 2023 05: +0', 0.85, '3096'],
#  ['Nov 18 2023 06: +0', 0.85, '2345'],
#  ['Nov 18 2023 07: +0', 0.85, '2744'],
#  ['Nov 18 2023 08: +0', 0.851, '2120'],
#  ['Nov 18 2023 09: +0', 0.85, '2442'],
#  ['Nov 18 2023 10: +0', 0.829, '2525'],
#  ['Nov 18 2023 11: +0', 0.826, '2915'],
#  ['Nov 18 2023 12: +0', 0.793, '2608'],
#  ['Nov 18 2023 13: +0', 0.8, '3512'],
#  ['Nov 18 2023 14: +0', 0.8, '3348'],
#  ['Nov 18 2023 15: +0', 0.8, '3654'],
#  ['Nov 18 2023 16: +0', 0.788, '3293'],
#  ['Nov 18 2023 17: +0', 0.793, '3926'],
#  ['Nov 18 2023 18: +0', 0.809, '3837'],
#  ['Nov 18 2023 19: +0', 0.8, '3823'],
#  ['Nov 18 2023 20: +0', 0.795, '3944'],
#  ['Nov 18 2023 21: +0', 0.798, '3495'],
#  ['Nov 18 2023 22: +0', 0.81, '3789'],
#  ['Nov 18 2023 23: +0', 0.815, '3112'],
#  ['Nov 19 2023 00: +0', 0.82, '2756'],
#  ['Nov 19 2023 01: +0', 0.84, '2249'],
#  ['Nov 19 2023 02: +0', 0.848, '2219'],
#  ['Nov 19 2023 03: +0', 0.85, '2766'],
#  ['Nov 19 2023 04: +0', 0.85, '2411'],
#  ['Nov 19 2023 05: +0', 0.86, '2656'],
#  ['Nov 19 2023 06: +0', 0.86, '2571'],
#  ['Nov 19 2023 07: +0', 0.86, '2926'],
#  ['Nov 19 2023 08: +0', 0.86, '2693'],
#  ['Nov 19 2023 09: +0', 0.864, '2892'],
#  ['Nov 19 2023 10: +0', 0.855, '2898'],
#  ['Nov 19 2023 11: +0', 0.82, '2236'],
#  ['Nov 19 2023 12: +0', 0.825, '3104'],
#  ['Nov 19 2023 13: +0', 0.81, '3429'],
#  ['Nov 19 2023 14: +0', 0.797, '3592'],
#  ['Nov 19 2023 15: +0', 0.793, '3391'],
#  ['Nov 19 2023 16: +0', 0.799, '3650'],
#  ['Nov 19 2023 17: +0', 0.793, '3358'],
#  ['Nov 19 2023 18: +0', 0.793, '3818'],
#  ['Nov 19 2023 19: +0', 0.782, '3899'],
#  ['Nov 19 2023 20: +0', 0.782, '3403']]

# %%
from app.src.mongo_controller import MongoController
from bson import ObjectId
url = "mongodb://mongodbuser:your_mongodb_root_password@localhost:27018"
mc = MongoController(url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> from app.src.mongo_controller import MongoController
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> from bson import ObjectId
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> url = "mongodb://mongodbuser:your_mongodb_root_password@localhost:27018"
#
# ModuleNotFoundError: No module named 'app.src.mongo_controller'

# %%
item = mc.price_history_coll.find_one({"_id": ObjectId("646166cf4d17d5e750152c56")})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> item = mc.price_history_coll.find_one({"_id": ObjectId("646166cf4d17d5e750152c56")})
#
# NameError: name 'mc' is not defined

# %%
def graph_price_history(datetimes, prices, title, locator: Locator = mdates.DayLocator(interval=5)):
    # plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    # plt.gca().xaxis.set_major_locator(locator)
    plt.plot(datetimes, prices)
    # plt.gcf().autofmt_xdate()
    plt.title(title)
    plt.show()

def show_plot_month(train_x, train_y, predicted_x, predicted_y, test_x, test_y, locator: Locator = mdates.MonthLocator(interval=2), title="empty title"):
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.gca().xaxis.set_major_locator(locator)
    plt.plot(train_x, train_y)
    plt.plot(test_x, test_y)
    plt.plot(predicted_x, predicted_y)
    plt.gcf().autofmt_xdate()
    plt.title(title)
    plt.show()

# %% [markdown]
# Получаем данные необходимые для обучения модели

# %%
prices = item['history']
parsed_datetimes = []
parsed_prices = []

for price in prices:
    dt: str = price[0]
    for k, v in replace_dates.items():
        dt=dt.replace(k, v)
    parsed_datetimes.append(datetime.strptime(dt, dt_format))
    parsed_prices.append(float(price[1]))
parsed_datetimes = np.array(parsed_datetimes)
parsed_datetimes =  np.array([dt.total_seconds() // 3600 for dt in (parsed_datetimes - parsed_datetimes[0])]).reshape(-1, 1)
parsed_prices = np.array(parsed_prices).reshape(-1, 1)
graph_price_history(parsed_datetimes, parsed_prices, unquote(item['name']), locator=mdates.MonthLocator(interval=100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> prices = item['history']
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> parsed_datetimes = []
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> parsed_prices = []
#
# TypeError: 'Item' object is not subscriptable

# %% [markdown]
# Нормируем историю цен, используя МинМакс нормализатор

# %%
scaler = MinMaxScaler()
scaler.fit(parsed_prices)
parsed_prices = scaler.transform(parsed_prices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> scaler = MinMaxScaler()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> scaler.fit(parsed_prices)
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> parsed_prices = scaler.transform(parsed_prices)
#
# NameError: name 'parsed_prices' is not defined

# %% [markdown]
# Так как в будущем у нас будет только история продаж, а нам нужно будет предугадать цену через несколько дней, не учитываем последние продажи при обучении

# %%
X_train = parsed_datetimes[:-100]
y_train = parsed_prices[:-100]

X_test = parsed_datetimes[-100:]
y_test = parsed_prices[-100:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> X_train = parsed_datetimes[:-100]
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> y_train = parsed_prices[:-100]
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> X_test = parsed_datetimes[-100:]
#
# NameError: name 'parsed_datetimes' is not defined

# %% [markdown]
# ### Модель линейной регрессии

# %%
lr = LinearRegression(copy_X=True)
lr.fit(X_train, y_train)

def func(X):
    y = X * lr.coef_ + lr.intercept_
    return y

print(lr.coef_, lr.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> lr = LinearRegression(copy_X=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> lr.fit(X_train, y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> def func(X):
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     y = X * lr.coef_ + lr.intercept_
#
# NameError: name 'X_train' is not defined

# %%
plt.plot(X_test, y_test)
# plt.plot(X_test, func(X_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(X_test, y_test)
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> # plt.plot(X_test, func(X_test))
#
# NameError: name 'X_test' is not defined

# %% [markdown]
# ### Модель линейной регрессии с регуляризацией L1

# %%
lr = Lasso(copy_X=True)
lr.fit(X_train_hours.reshape(-1, 1), y_train)

def func(X):
    y = X * lr.coef_ + lr.intercept_
    return y

print(lr.coef_, lr.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 20 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> lr = Lasso(copy_X=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> lr.fit(X_train_hours.reshape(-1, 1), y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> def func(X):
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a>     y = X * lr.coef_ + lr.intercept_
#
# NameError: name 'X_train_hours' is not defined

# %%
show_plot_month(X_train, y_train, parsed_datetimes, func(full_x_hours)[0], X_test, y_test, title=unquote(item['name']), locator=mdates.MonthLocator(interval=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> show_plot_month(X_train, y_train, parsed_datetimes, func(full_x_hours)[0], X_test, y_test, title=unquote(item['name']), locator=mdates.MonthLocator(interval=2))
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### Модель линейной регрессии с регуляризацией L2

# %%
lr = Ridge(copy_X=True)
lr.fit(X_train_hours.reshape(-1, 1), y_train)

def func(X):
    y = X * lr.coef_ + lr.intercept_
    return y

print(lr.coef_, lr.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 23 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> lr = Ridge(copy_X=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> lr.fit(X_train_hours.reshape(-1, 1), y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a> def func(X):
#       <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a>     y = X * lr.coef_ + lr.intercept_
#
# NameError: name 'X_train_hours' is not defined

# %%
show_plot_month(X_train, y_train, parsed_datetimes, func(full_x_hours)[0], X_test, y_test, title=unquote(item['name']), locator=mdates.MonthLocator(interval=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> show_plot_month(X_train, y_train, parsed_datetimes, func(full_x_hours)[0], X_test, y_test, title=unquote(item['name']), locator=mdates.MonthLocator(interval=2))
#
# NameError: name 'X_train' is not defined

# %%
func(full_x_hours)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\OMEN\Desktop\mireapractice\steamapi.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OMEN/Desktop/mireapractice/steamapi.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> func(full_x_hours)[0]
#
# NameError: name 'func' is not defined

# %%
scaler = MinMaxScaler()
scaler.fit(parsed_prices.reshape(-1, 1))
transformed = scaler.transform(parsed_prices.reshape(-1, 1))

# %%
plt.plot(full_x_hours, transformed)

# %%
full_x_hours
# Out:
# array([    0.,    24.,    48., ..., 21424., 21428., 21429.])

# %%
import numpy as np
from matplotlib import pyplot as plt
from app.src.steamapi.steamapi import SteamParser
from app.src.prediction import PredictionModel
item_id, history, labels = SteamParser.get_item("Sticker%20%7C%20Ultraviolet%20Poison%20Frog%20%28Foil%29", 730)
labels_hours = np.array([dt.total_seconds() // 3600 for dt in (np.array(labels) - labels[0])]).reshape(-1, 1)

# %%
pm = PredictionModel(history[-400:-100], labels[-400:-100], labels[0])
pm.transform_data()
pm.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pm = PredictionModel(history[-400:-100], labels[-400:-100], labels[0])
#       2 pm.transform_data()
#       3 pm.train()
#
# NameError: name 'PredictionModel' is not defined

# %%
plt.plot(labels_hours, history)
plt.plot(labels_hours, pm.func(labels_hours))

# %%
labels
# Out:
# [datetime.datetime(2021, 9, 22, 1, 0),
#  datetime.datetime(2021, 9, 23, 1, 0),
#  datetime.datetime(2021, 9, 24, 1, 0),
#  datetime.datetime(2021, 9, 25, 1, 0),
#  datetime.datetime(2021, 9, 26, 1, 0),
#  datetime.datetime(2021, 9, 27, 1, 0),
#  datetime.datetime(2021, 9, 28, 1, 0),
#  datetime.datetime(2021, 9, 29, 1, 0),
#  datetime.datetime(2021, 9, 30, 1, 0),
#  datetime.datetime(2021, 10, 1, 1, 0),
#  datetime.datetime(2021, 10, 2, 1, 0),
#  datetime.datetime(2021, 10, 3, 1, 0),
#  datetime.datetime(2021, 10, 4, 1, 0),
#  datetime.datetime(2021, 10, 5, 1, 0),
#  datetime.datetime(2021, 10, 6, 1, 0),
#  datetime.datetime(2021, 10, 7, 1, 0),
#  datetime.datetime(2021, 10, 8, 1, 0),
#  datetime.datetime(2021, 10, 9, 1, 0),
#  datetime.datetime(2021, 10, 10, 1, 0),
#  datetime.datetime(2021, 10, 11, 1, 0),
#  datetime.datetime(2021, 10, 12, 1, 0),
#  datetime.datetime(2021, 10, 13, 1, 0),
#  datetime.datetime(2021, 10, 14, 1, 0),
#  datetime.datetime(2021, 10, 15, 1, 0),
#  datetime.datetime(2021, 10, 16, 1, 0),
#  datetime.datetime(2021, 10, 17, 1, 0),
#  datetime.datetime(2021, 10, 18, 1, 0),
#  datetime.datetime(2021, 10, 19, 1, 0),
#  datetime.datetime(2021, 10, 20, 1, 0),
#  datetime.datetime(2021, 10, 21, 1, 0),
#  datetime.datetime(2021, 10, 22, 1, 0),
#  datetime.datetime(2021, 10, 23, 1, 0),
#  datetime.datetime(2021, 10, 24, 1, 0),
#  datetime.datetime(2021, 10, 25, 1, 0),
#  datetime.datetime(2021, 10, 26, 1, 0),
#  datetime.datetime(2021, 10, 27, 1, 0),
#  datetime.datetime(2021, 10, 28, 1, 0),
#  datetime.datetime(2021, 10, 29, 1, 0),
#  datetime.datetime(2021, 10, 30, 1, 0),
#  datetime.datetime(2021, 10, 31, 1, 0),
#  datetime.datetime(2021, 11, 1, 1, 0),
#  datetime.datetime(2021, 11, 2, 1, 0),
#  datetime.datetime(2021, 11, 3, 1, 0),
#  datetime.datetime(2021, 11, 4, 1, 0),
#  datetime.datetime(2021, 11, 5, 1, 0),
#  datetime.datetime(2021, 11, 6, 1, 0),
#  datetime.datetime(2021, 11, 7, 1, 0),
#  datetime.datetime(2021, 11, 8, 1, 0),
#  datetime.datetime(2021, 11, 9, 1, 0),
#  datetime.datetime(2021, 11, 10, 1, 0),
#  datetime.datetime(2021, 11, 11, 1, 0),
#  datetime.datetime(2021, 11, 12, 1, 0),
#  datetime.datetime(2021, 11, 13, 1, 0),
#  datetime.datetime(2021, 11, 14, 1, 0),
#  datetime.datetime(2021, 11, 15, 1, 0),
#  datetime.datetime(2021, 11, 16, 1, 0),
#  datetime.datetime(2021, 11, 17, 1, 0),
#  datetime.datetime(2021, 11, 18, 1, 0),
#  datetime.datetime(2021, 11, 19, 1, 0),
#  datetime.datetime(2021, 11, 20, 1, 0),
#  datetime.datetime(2021, 11, 21, 1, 0),
#  datetime.datetime(2021, 11, 22, 1, 0),
#  datetime.datetime(2021, 11, 23, 1, 0),
#  datetime.datetime(2021, 11, 24, 1, 0),
#  datetime.datetime(2021, 11, 25, 1, 0),
#  datetime.datetime(2021, 11, 26, 1, 0),
#  datetime.datetime(2021, 11, 27, 1, 0),
#  datetime.datetime(2021, 11, 28, 1, 0),
#  datetime.datetime(2021, 11, 29, 1, 0),
#  datetime.datetime(2021, 11, 30, 1, 0),
#  datetime.datetime(2021, 12, 1, 1, 0),
#  datetime.datetime(2021, 12, 2, 1, 0),
#  datetime.datetime(2021, 12, 3, 1, 0),
#  datetime.datetime(2021, 12, 4, 1, 0),
#  datetime.datetime(2021, 12, 5, 1, 0),
#  datetime.datetime(2021, 12, 6, 1, 0),
#  datetime.datetime(2021, 12, 7, 1, 0),
#  datetime.datetime(2021, 12, 8, 1, 0),
#  datetime.datetime(2021, 12, 9, 1, 0),
#  datetime.datetime(2021, 12, 10, 1, 0),
#  datetime.datetime(2021, 12, 11, 1, 0),
#  datetime.datetime(2021, 12, 12, 1, 0),
#  datetime.datetime(2021, 12, 13, 1, 0),
#  datetime.datetime(2021, 12, 14, 1, 0),
#  datetime.datetime(2021, 12, 15, 1, 0),
#  datetime.datetime(2021, 12, 16, 1, 0),
#  datetime.datetime(2021, 12, 17, 1, 0),
#  datetime.datetime(2021, 12, 18, 1, 0),
#  datetime.datetime(2021, 12, 19, 1, 0),
#  datetime.datetime(2021, 12, 20, 1, 0),
#  datetime.datetime(2021, 12, 21, 1, 0),
#  datetime.datetime(2021, 12, 22, 1, 0),
#  datetime.datetime(2021, 12, 23, 1, 0),
#  datetime.datetime(2021, 12, 24, 1, 0),
#  datetime.datetime(2021, 12, 25, 1, 0),
#  datetime.datetime(2021, 12, 26, 1, 0),
#  datetime.datetime(2021, 12, 27, 1, 0),
#  datetime.datetime(2021, 12, 28, 1, 0),
#  datetime.datetime(2021, 12, 29, 1, 0),
#  datetime.datetime(2021, 12, 30, 1, 0),
#  datetime.datetime(2021, 12, 31, 1, 0),
#  datetime.datetime(2022, 1, 1, 1, 0),
#  datetime.datetime(2022, 1, 2, 1, 0),
#  datetime.datetime(2022, 1, 3, 1, 0),
#  datetime.datetime(2022, 1, 4, 1, 0),
#  datetime.datetime(2022, 1, 5, 1, 0),
#  datetime.datetime(2022, 1, 6, 1, 0),
#  datetime.datetime(2022, 1, 7, 1, 0),
#  datetime.datetime(2022, 1, 8, 1, 0),
#  datetime.datetime(2022, 1, 9, 1, 0),
#  datetime.datetime(2022, 1, 10, 1, 0),
#  datetime.datetime(2022, 1, 11, 1, 0),
#  datetime.datetime(2022, 1, 12, 1, 0),
#  datetime.datetime(2022, 1, 13, 1, 0),
#  datetime.datetime(2022, 1, 14, 1, 0),
#  datetime.datetime(2022, 1, 15, 1, 0),
#  datetime.datetime(2022, 1, 16, 1, 0),
#  datetime.datetime(2022, 1, 17, 1, 0),
#  datetime.datetime(2022, 1, 18, 1, 0),
#  datetime.datetime(2022, 1, 19, 1, 0),
#  datetime.datetime(2022, 1, 20, 1, 0),
#  datetime.datetime(2022, 1, 21, 1, 0),
#  datetime.datetime(2022, 1, 22, 1, 0),
#  datetime.datetime(2022, 1, 23, 1, 0),
#  datetime.datetime(2022, 1, 24, 1, 0),
#  datetime.datetime(2022, 1, 25, 1, 0),
#  datetime.datetime(2022, 1, 26, 1, 0),
#  datetime.datetime(2022, 1, 27, 1, 0),
#  datetime.datetime(2022, 1, 28, 1, 0),
#  datetime.datetime(2022, 1, 29, 1, 0),
#  datetime.datetime(2022, 1, 30, 1, 0),
#  datetime.datetime(2022, 1, 31, 1, 0),
#  datetime.datetime(2022, 2, 1, 1, 0),
#  datetime.datetime(2022, 2, 2, 1, 0),
#  datetime.datetime(2022, 2, 3, 1, 0),
#  datetime.datetime(2022, 2, 4, 1, 0),
#  datetime.datetime(2022, 2, 5, 1, 0),
#  datetime.datetime(2022, 2, 6, 1, 0),
#  datetime.datetime(2022, 2, 7, 1, 0),
#  datetime.datetime(2022, 2, 8, 1, 0),
#  datetime.datetime(2022, 2, 9, 1, 0),
#  datetime.datetime(2022, 2, 10, 1, 0),
#  datetime.datetime(2022, 2, 11, 1, 0),
#  datetime.datetime(2022, 2, 12, 1, 0),
#  datetime.datetime(2022, 2, 13, 1, 0),
#  datetime.datetime(2022, 2, 14, 1, 0),
#  datetime.datetime(2022, 2, 15, 1, 0),
#  datetime.datetime(2022, 2, 16, 1, 0),
#  datetime.datetime(2022, 2, 17, 1, 0),
#  datetime.datetime(2022, 2, 18, 1, 0),
#  datetime.datetime(2022, 2, 19, 1, 0),
#  datetime.datetime(2022, 2, 20, 1, 0),
#  datetime.datetime(2022, 2, 21, 1, 0),
#  datetime.datetime(2022, 2, 22, 1, 0),
#  datetime.datetime(2022, 2, 23, 1, 0),
#  datetime.datetime(2022, 2, 24, 1, 0),
#  datetime.datetime(2022, 2, 25, 1, 0),
#  datetime.datetime(2022, 2, 26, 1, 0),
#  datetime.datetime(2022, 2, 27, 1, 0),
#  datetime.datetime(2022, 2, 28, 1, 0),
#  datetime.datetime(2022, 3, 1, 1, 0),
#  datetime.datetime(2022, 3, 2, 1, 0),
#  datetime.datetime(2022, 3, 3, 1, 0),
#  datetime.datetime(2022, 3, 4, 1, 0),
#  datetime.datetime(2022, 3, 5, 1, 0),
#  datetime.datetime(2022, 3, 6, 1, 0),
#  datetime.datetime(2022, 3, 7, 1, 0),
#  datetime.datetime(2022, 3, 8, 1, 0),
#  datetime.datetime(2022, 3, 9, 1, 0),
#  datetime.datetime(2022, 3, 10, 1, 0),
#  datetime.datetime(2022, 3, 11, 1, 0),
#  datetime.datetime(2022, 3, 12, 1, 0),
#  datetime.datetime(2022, 3, 13, 1, 0),
#  datetime.datetime(2022, 3, 14, 1, 0),
#  datetime.datetime(2022, 3, 15, 1, 0),
#  datetime.datetime(2022, 3, 16, 1, 0),
#  datetime.datetime(2022, 3, 17, 1, 0),
#  datetime.datetime(2022, 3, 18, 1, 0),
#  datetime.datetime(2022, 3, 19, 1, 0),
#  datetime.datetime(2022, 3, 20, 1, 0),
#  datetime.datetime(2022, 3, 21, 1, 0),
#  datetime.datetime(2022, 3, 22, 1, 0),
#  datetime.datetime(2022, 3, 23, 1, 0),
#  datetime.datetime(2022, 3, 24, 1, 0),
#  datetime.datetime(2022, 3, 25, 1, 0),
#  datetime.datetime(2022, 3, 26, 1, 0),
#  datetime.datetime(2022, 3, 27, 1, 0),
#  datetime.datetime(2022, 3, 28, 1, 0),
#  datetime.datetime(2022, 3, 29, 1, 0),
#  datetime.datetime(2022, 3, 30, 1, 0),
#  datetime.datetime(2022, 3, 31, 1, 0),
#  datetime.datetime(2022, 4, 1, 1, 0),
#  datetime.datetime(2022, 4, 2, 1, 0),
#  datetime.datetime(2022, 4, 3, 1, 0),
#  datetime.datetime(2022, 4, 4, 1, 0),
#  datetime.datetime(2022, 4, 5, 1, 0),
#  datetime.datetime(2022, 4, 6, 1, 0),
#  datetime.datetime(2022, 4, 7, 1, 0),
#  datetime.datetime(2022, 4, 8, 1, 0),
#  datetime.datetime(2022, 4, 9, 1, 0),
#  datetime.datetime(2022, 4, 10, 1, 0),
#  datetime.datetime(2022, 4, 11, 1, 0),
#  datetime.datetime(2022, 4, 12, 1, 0),
#  datetime.datetime(2022, 4, 13, 1, 0),
#  datetime.datetime(2022, 4, 14, 1, 0),
#  datetime.datetime(2022, 4, 15, 1, 0),
#  datetime.datetime(2022, 4, 16, 1, 0),
#  datetime.datetime(2022, 4, 17, 1, 0),
#  datetime.datetime(2022, 4, 18, 1, 0),
#  datetime.datetime(2022, 4, 19, 1, 0),
#  datetime.datetime(2022, 4, 20, 1, 0),
#  datetime.datetime(2022, 4, 21, 1, 0),
#  datetime.datetime(2022, 4, 22, 1, 0),
#  datetime.datetime(2022, 4, 23, 1, 0),
#  datetime.datetime(2022, 4, 24, 1, 0),
#  datetime.datetime(2022, 4, 25, 1, 0),
#  datetime.datetime(2022, 4, 26, 1, 0),
#  datetime.datetime(2022, 4, 27, 1, 0),
#  datetime.datetime(2022, 4, 28, 1, 0),
#  datetime.datetime(2022, 4, 29, 1, 0),
#  datetime.datetime(2022, 4, 30, 1, 0),
#  datetime.datetime(2022, 5, 1, 1, 0),
#  datetime.datetime(2022, 5, 2, 1, 0),
#  datetime.datetime(2022, 5, 3, 1, 0),
#  datetime.datetime(2022, 5, 4, 1, 0),
#  datetime.datetime(2022, 5, 5, 1, 0),
#  datetime.datetime(2022, 5, 6, 1, 0),
#  datetime.datetime(2022, 5, 7, 1, 0),
#  datetime.datetime(2022, 5, 8, 1, 0),
#  datetime.datetime(2022, 5, 9, 1, 0),
#  datetime.datetime(2022, 5, 10, 1, 0),
#  datetime.datetime(2022, 5, 11, 1, 0),
#  datetime.datetime(2022, 5, 12, 1, 0),
#  datetime.datetime(2022, 5, 13, 1, 0),
#  datetime.datetime(2022, 5, 14, 1, 0),
#  datetime.datetime(2022, 5, 15, 1, 0),
#  datetime.datetime(2022, 5, 16, 1, 0),
#  datetime.datetime(2022, 5, 17, 1, 0),
#  datetime.datetime(2022, 5, 18, 1, 0),
#  datetime.datetime(2022, 5, 19, 1, 0),
#  datetime.datetime(2022, 5, 20, 1, 0),
#  datetime.datetime(2022, 5, 21, 1, 0),
#  datetime.datetime(2022, 5, 22, 1, 0),
#  datetime.datetime(2022, 5, 23, 1, 0),
#  datetime.datetime(2022, 5, 24, 1, 0),
#  datetime.datetime(2022, 5, 25, 1, 0),
#  datetime.datetime(2022, 5, 26, 1, 0),
#  datetime.datetime(2022, 5, 27, 1, 0),
#  datetime.datetime(2022, 5, 28, 1, 0),
#  datetime.datetime(2022, 5, 29, 1, 0),
#  datetime.datetime(2022, 5, 30, 1, 0),
#  datetime.datetime(2022, 5, 31, 1, 0),
#  datetime.datetime(2022, 6, 1, 1, 0),
#  datetime.datetime(2022, 6, 2, 1, 0),
#  datetime.datetime(2022, 6, 3, 1, 0),
#  datetime.datetime(2022, 6, 4, 1, 0),
#  datetime.datetime(2022, 6, 5, 1, 0),
#  datetime.datetime(2022, 6, 6, 1, 0),
#  datetime.datetime(2022, 6, 7, 1, 0),
#  datetime.datetime(2022, 6, 8, 1, 0),
#  datetime.datetime(2022, 6, 9, 1, 0),
#  datetime.datetime(2022, 6, 10, 1, 0),
#  datetime.datetime(2022, 6, 11, 1, 0),
#  datetime.datetime(2022, 6, 12, 1, 0),
#  datetime.datetime(2022, 6, 13, 1, 0),
#  datetime.datetime(2022, 6, 14, 1, 0),
#  datetime.datetime(2022, 6, 15, 1, 0),
#  datetime.datetime(2022, 6, 16, 1, 0),
#  datetime.datetime(2022, 6, 17, 1, 0),
#  datetime.datetime(2022, 6, 18, 1, 0),
#  datetime.datetime(2022, 6, 19, 1, 0),
#  datetime.datetime(2022, 6, 20, 1, 0),
#  datetime.datetime(2022, 6, 21, 1, 0),
#  datetime.datetime(2022, 6, 22, 1, 0),
#  datetime.datetime(2022, 6, 23, 1, 0),
#  datetime.datetime(2022, 6, 24, 1, 0),
#  datetime.datetime(2022, 6, 25, 1, 0),
#  datetime.datetime(2022, 6, 26, 1, 0),
#  datetime.datetime(2022, 6, 27, 1, 0),
#  datetime.datetime(2022, 6, 28, 1, 0),
#  datetime.datetime(2022, 6, 29, 1, 0),
#  datetime.datetime(2022, 6, 30, 1, 0),
#  datetime.datetime(2022, 7, 1, 1, 0),
#  datetime.datetime(2022, 7, 2, 1, 0),
#  datetime.datetime(2022, 7, 3, 1, 0),
#  datetime.datetime(2022, 7, 4, 1, 0),
#  datetime.datetime(2022, 7, 5, 1, 0),
#  datetime.datetime(2022, 7, 6, 1, 0),
#  datetime.datetime(2022, 7, 7, 1, 0),
#  datetime.datetime(2022, 7, 8, 1, 0),
#  datetime.datetime(2022, 7, 9, 1, 0),
#  datetime.datetime(2022, 7, 10, 1, 0),
#  datetime.datetime(2022, 7, 11, 1, 0),
#  datetime.datetime(2022, 7, 12, 1, 0),
#  datetime.datetime(2022, 7, 13, 1, 0),
#  datetime.datetime(2022, 7, 14, 1, 0),
#  datetime.datetime(2022, 7, 15, 1, 0),
#  datetime.datetime(2022, 7, 16, 1, 0),
#  datetime.datetime(2022, 7, 17, 1, 0),
#  datetime.datetime(2022, 7, 18, 1, 0),
#  datetime.datetime(2022, 7, 19, 1, 0),
#  datetime.datetime(2022, 7, 20, 1, 0),
#  datetime.datetime(2022, 7, 21, 1, 0),
#  datetime.datetime(2022, 7, 22, 1, 0),
#  datetime.datetime(2022, 7, 23, 1, 0),
#  datetime.datetime(2022, 7, 24, 1, 0),
#  datetime.datetime(2022, 7, 25, 1, 0),
#  datetime.datetime(2022, 7, 26, 1, 0),
#  datetime.datetime(2022, 7, 27, 1, 0),
#  datetime.datetime(2022, 7, 28, 1, 0),
#  datetime.datetime(2022, 7, 29, 1, 0),
#  datetime.datetime(2022, 7, 30, 1, 0),
#  datetime.datetime(2022, 7, 31, 1, 0),
#  datetime.datetime(2022, 8, 1, 1, 0),
#  datetime.datetime(2022, 8, 2, 1, 0),
#  datetime.datetime(2022, 8, 3, 1, 0),
#  datetime.datetime(2022, 8, 4, 1, 0),
#  datetime.datetime(2022, 8, 5, 1, 0),
#  datetime.datetime(2022, 8, 6, 1, 0),
#  datetime.datetime(2022, 8, 7, 1, 0),
#  datetime.datetime(2022, 8, 8, 1, 0),
#  datetime.datetime(2022, 8, 9, 1, 0),
#  datetime.datetime(2022, 8, 10, 1, 0),
#  datetime.datetime(2022, 8, 11, 1, 0),
#  datetime.datetime(2022, 8, 12, 1, 0),
#  datetime.datetime(2022, 8, 13, 1, 0),
#  datetime.datetime(2022, 8, 14, 1, 0),
#  datetime.datetime(2022, 8, 15, 1, 0),
#  datetime.datetime(2022, 8, 17, 1, 0),
#  datetime.datetime(2022, 8, 18, 1, 0),
#  datetime.datetime(2022, 8, 19, 1, 0),
#  datetime.datetime(2022, 8, 20, 1, 0),
#  datetime.datetime(2022, 8, 21, 1, 0),
#  datetime.datetime(2022, 8, 22, 1, 0),
#  datetime.datetime(2022, 8, 23, 1, 0),
#  datetime.datetime(2022, 8, 24, 1, 0),
#  datetime.datetime(2022, 8, 25, 1, 0),
#  datetime.datetime(2022, 8, 26, 1, 0),
#  datetime.datetime(2022, 8, 27, 1, 0),
#  datetime.datetime(2022, 8, 28, 1, 0),
#  datetime.datetime(2022, 8, 29, 1, 0),
#  datetime.datetime(2022, 8, 30, 1, 0),
#  datetime.datetime(2022, 8, 31, 1, 0),
#  datetime.datetime(2022, 9, 1, 1, 0),
#  datetime.datetime(2022, 9, 2, 1, 0),
#  datetime.datetime(2022, 9, 3, 1, 0),
#  datetime.datetime(2022, 9, 4, 1, 0),
#  datetime.datetime(2022, 9, 5, 1, 0),
#  datetime.datetime(2022, 9, 6, 1, 0),
#  datetime.datetime(2022, 9, 7, 1, 0),
#  datetime.datetime(2022, 9, 8, 1, 0),
#  datetime.datetime(2022, 9, 9, 1, 0),
#  datetime.datetime(2022, 9, 10, 1, 0),
#  datetime.datetime(2022, 9, 11, 1, 0),
#  datetime.datetime(2022, 9, 12, 1, 0),
#  datetime.datetime(2022, 9, 13, 1, 0),
#  datetime.datetime(2022, 9, 14, 1, 0),
#  datetime.datetime(2022, 9, 15, 1, 0),
#  datetime.datetime(2022, 9, 16, 1, 0),
#  datetime.datetime(2022, 9, 17, 1, 0),
#  datetime.datetime(2022, 9, 18, 1, 0),
#  datetime.datetime(2022, 9, 19, 1, 0),
#  datetime.datetime(2022, 9, 20, 1, 0),
#  datetime.datetime(2022, 9, 21, 1, 0),
#  datetime.datetime(2022, 9, 22, 1, 0),
#  datetime.datetime(2022, 9, 23, 1, 0),
#  datetime.datetime(2022, 9, 24, 1, 0),
#  datetime.datetime(2022, 9, 25, 1, 0),
#  datetime.datetime(2022, 9, 26, 1, 0),
#  datetime.datetime(2022, 9, 27, 1, 0),
#  datetime.datetime(2022, 9, 28, 1, 0),
#  datetime.datetime(2022, 9, 29, 1, 0),
#  datetime.datetime(2022, 9, 30, 1, 0),
#  datetime.datetime(2022, 10, 1, 1, 0),
#  datetime.datetime(2022, 10, 2, 1, 0),
#  datetime.datetime(2022, 10, 3, 1, 0),
#  datetime.datetime(2022, 10, 4, 1, 0),
#  datetime.datetime(2022, 10, 5, 1, 0),
#  datetime.datetime(2022, 10, 7, 1, 0),
#  datetime.datetime(2022, 10, 8, 1, 0),
#  datetime.datetime(2022, 10, 9, 1, 0),
#  datetime.datetime(2022, 10, 10, 1, 0),
#  datetime.datetime(2022, 10, 11, 1, 0),
#  datetime.datetime(2022, 10, 12, 1, 0),
#  datetime.datetime(2022, 10, 13, 1, 0),
#  datetime.datetime(2022, 10, 14, 1, 0),
#  datetime.datetime(2022, 10, 15, 1, 0),
#  datetime.datetime(2022, 10, 16, 1, 0),
#  datetime.datetime(2022, 10, 17, 1, 0),
#  datetime.datetime(2022, 10, 18, 1, 0),
#  datetime.datetime(2022, 10, 19, 1, 0),
#  datetime.datetime(2022, 10, 20, 1, 0),
#  datetime.datetime(2022, 10, 21, 1, 0),
#  datetime.datetime(2022, 10, 22, 1, 0),
#  datetime.datetime(2022, 10, 23, 1, 0),
#  datetime.datetime(2022, 10, 24, 1, 0),
#  datetime.datetime(2022, 10, 25, 1, 0),
#  datetime.datetime(2022, 10, 26, 1, 0),
#  datetime.datetime(2022, 10, 27, 1, 0),
#  datetime.datetime(2022, 10, 28, 1, 0),
#  datetime.datetime(2022, 10, 29, 1, 0),
#  datetime.datetime(2022, 10, 30, 1, 0),
#  datetime.datetime(2022, 10, 31, 1, 0),
#  datetime.datetime(2022, 11, 1, 1, 0),
#  datetime.datetime(2022, 11, 2, 1, 0),
#  datetime.datetime(2022, 11, 3, 1, 0),
#  datetime.datetime(2022, 11, 6, 1, 0),
#  datetime.datetime(2022, 11, 7, 1, 0),
#  datetime.datetime(2022, 11, 8, 1, 0),
#  datetime.datetime(2022, 11, 9, 1, 0),
#  datetime.datetime(2022, 11, 10, 1, 0),
#  datetime.datetime(2022, 11, 11, 1, 0),
#  datetime.datetime(2022, 11, 12, 1, 0),
#  datetime.datetime(2022, 11, 13, 1, 0),
#  datetime.datetime(2022, 11, 14, 1, 0),
#  datetime.datetime(2022, 11, 15, 1, 0),
#  datetime.datetime(2022, 11, 16, 1, 0),
#  datetime.datetime(2022, 11, 17, 1, 0),
#  datetime.datetime(2022, 11, 18, 1, 0),
#  datetime.datetime(2022, 11, 19, 1, 0),
#  datetime.datetime(2022, 11, 20, 1, 0),
#  datetime.datetime(2022, 11, 21, 1, 0),
#  datetime.datetime(2022, 11, 22, 1, 0),
#  datetime.datetime(2022, 11, 23, 1, 0),
#  datetime.datetime(2022, 11, 24, 1, 0),
#  datetime.datetime(2022, 11, 25, 1, 0),
#  datetime.datetime(2022, 11, 27, 1, 0),
#  datetime.datetime(2022, 11, 28, 1, 0),
#  datetime.datetime(2022, 11, 29, 1, 0),
#  datetime.datetime(2022, 11, 30, 1, 0),
#  datetime.datetime(2022, 12, 1, 1, 0),
#  datetime.datetime(2022, 12, 2, 1, 0),
#  datetime.datetime(2022, 12, 3, 1, 0),
#  datetime.datetime(2022, 12, 4, 1, 0),
#  datetime.datetime(2022, 12, 5, 1, 0),
#  datetime.datetime(2022, 12, 6, 1, 0),
#  datetime.datetime(2022, 12, 7, 1, 0),
#  datetime.datetime(2022, 12, 8, 1, 0),
#  datetime.datetime(2022, 12, 9, 1, 0),
#  datetime.datetime(2022, 12, 10, 1, 0),
#  datetime.datetime(2022, 12, 11, 1, 0),
#  datetime.datetime(2022, 12, 12, 1, 0),
#  datetime.datetime(2022, 12, 13, 1, 0),
#  datetime.datetime(2022, 12, 14, 1, 0),
#  datetime.datetime(2022, 12, 15, 1, 0),
#  datetime.datetime(2022, 12, 16, 1, 0),
#  datetime.datetime(2022, 12, 17, 1, 0),
#  datetime.datetime(2022, 12, 18, 1, 0),
#  datetime.datetime(2022, 12, 19, 1, 0),
#  datetime.datetime(2022, 12, 20, 1, 0),
#  datetime.datetime(2022, 12, 21, 1, 0),
#  datetime.datetime(2022, 12, 22, 1, 0),
#  datetime.datetime(2022, 12, 23, 1, 0),
#  datetime.datetime(2022, 12, 24, 1, 0),
#  datetime.datetime(2022, 12, 25, 1, 0),
#  datetime.datetime(2022, 12, 26, 1, 0),
#  datetime.datetime(2022, 12, 27, 1, 0),
#  datetime.datetime(2022, 12, 28, 1, 0),
#  datetime.datetime(2022, 12, 29, 1, 0),
#  datetime.datetime(2022, 12, 30, 1, 0),
#  datetime.datetime(2022, 12, 31, 1, 0),
#  datetime.datetime(2023, 1, 1, 1, 0),
#  datetime.datetime(2023, 1, 2, 1, 0),
#  datetime.datetime(2023, 1, 3, 1, 0),
#  datetime.datetime(2023, 1, 4, 1, 0),
#  datetime.datetime(2023, 1, 5, 1, 0),
#  datetime.datetime(2023, 1, 6, 1, 0),
#  datetime.datetime(2023, 1, 7, 1, 0),
#  datetime.datetime(2023, 1, 8, 1, 0),
#  datetime.datetime(2023, 1, 9, 1, 0),
#  datetime.datetime(2023, 1, 10, 1, 0),
#  datetime.datetime(2023, 1, 11, 1, 0),
#  datetime.datetime(2023, 1, 12, 1, 0),
#  datetime.datetime(2023, 1, 13, 1, 0),
#  datetime.datetime(2023, 1, 14, 1, 0),
#  datetime.datetime(2023, 1, 15, 1, 0),
#  datetime.datetime(2023, 1, 16, 1, 0),
#  datetime.datetime(2023, 1, 17, 1, 0),
#  datetime.datetime(2023, 1, 19, 1, 0),
#  datetime.datetime(2023, 1, 20, 1, 0),
#  datetime.datetime(2023, 1, 21, 1, 0),
#  datetime.datetime(2023, 1, 22, 1, 0),
#  datetime.datetime(2023, 1, 23, 1, 0),
#  datetime.datetime(2023, 1, 24, 1, 0),
#  datetime.datetime(2023, 1, 25, 1, 0),
#  datetime.datetime(2023, 1, 26, 1, 0),
#  datetime.datetime(2023, 1, 27, 1, 0),
#  datetime.datetime(2023, 1, 28, 1, 0),
#  datetime.datetime(2023, 1, 29, 1, 0),
#  datetime.datetime(2023, 1, 30, 1, 0),
#  datetime.datetime(2023, 1, 31, 1, 0),
#  datetime.datetime(2023, 2, 1, 1, 0),
#  datetime.datetime(2023, 2, 2, 1, 0),
#  datetime.datetime(2023, 2, 3, 1, 0),
#  datetime.datetime(2023, 2, 4, 1, 0),
#  datetime.datetime(2023, 2, 5, 1, 0),
#  datetime.datetime(2023, 2, 6, 1, 0),
#  datetime.datetime(2023, 2, 7, 1, 0),
#  datetime.datetime(2023, 2, 8, 1, 0),
#  datetime.datetime(2023, 2, 9, 1, 0),
#  datetime.datetime(2023, 2, 10, 1, 0),
#  datetime.datetime(2023, 2, 11, 1, 0),
#  datetime.datetime(2023, 2, 12, 1, 0),
#  datetime.datetime(2023, 2, 14, 1, 0),
#  datetime.datetime(2023, 2, 16, 1, 0),
#  datetime.datetime(2023, 2, 17, 1, 0),
#  datetime.datetime(2023, 2, 18, 1, 0),
#  datetime.datetime(2023, 2, 19, 1, 0),
#  datetime.datetime(2023, 2, 20, 1, 0),
#  datetime.datetime(2023, 2, 21, 1, 0),
#  datetime.datetime(2023, 2, 22, 1, 0),
#  datetime.datetime(2023, 2, 23, 1, 0),
#  datetime.datetime(2023, 2, 24, 1, 0),
#  datetime.datetime(2023, 2, 25, 1, 0),
#  datetime.datetime(2023, 2, 26, 1, 0),
#  datetime.datetime(2023, 2, 27, 1, 0),
#  datetime.datetime(2023, 2, 28, 1, 0),
#  datetime.datetime(2023, 3, 1, 1, 0),
#  datetime.datetime(2023, 3, 2, 1, 0),
#  datetime.datetime(2023, 3, 3, 1, 0),
#  datetime.datetime(2023, 3, 4, 1, 0),
#  datetime.datetime(2023, 3, 5, 1, 0),
#  datetime.datetime(2023, 3, 6, 1, 0),
#  datetime.datetime(2023, 3, 7, 1, 0),
#  datetime.datetime(2023, 3, 8, 1, 0),
#  datetime.datetime(2023, 3, 9, 1, 0),
#  datetime.datetime(2023, 3, 10, 1, 0),
#  datetime.datetime(2023, 3, 11, 1, 0),
#  datetime.datetime(2023, 3, 12, 1, 0),
#  datetime.datetime(2023, 3, 13, 1, 0),
#  datetime.datetime(2023, 3, 14, 1, 0),
#  datetime.datetime(2023, 3, 15, 1, 0),
#  datetime.datetime(2023, 3, 16, 1, 0),
#  datetime.datetime(2023, 3, 17, 1, 0),
#  datetime.datetime(2023, 3, 18, 1, 0),
#  datetime.datetime(2023, 3, 19, 1, 0),
#  datetime.datetime(2023, 3, 20, 1, 0),
#  datetime.datetime(2023, 3, 21, 1, 0),
#  datetime.datetime(2023, 3, 22, 1, 0),
#  datetime.datetime(2023, 3, 23, 1, 0),
#  datetime.datetime(2023, 3, 24, 1, 0),
#  datetime.datetime(2023, 3, 25, 1, 0),
#  datetime.datetime(2023, 3, 26, 1, 0),
#  datetime.datetime(2023, 3, 27, 1, 0),
#  datetime.datetime(2023, 3, 28, 1, 0),
#  datetime.datetime(2023, 3, 29, 1, 0),
#  datetime.datetime(2023, 3, 30, 1, 0),
#  datetime.datetime(2023, 3, 31, 1, 0),
#  datetime.datetime(2023, 4, 1, 1, 0),
#  datetime.datetime(2023, 4, 2, 1, 0),
#  datetime.datetime(2023, 4, 3, 1, 0),
#  datetime.datetime(2023, 4, 4, 1, 0),
#  datetime.datetime(2023, 4, 5, 1, 0),
#  datetime.datetime(2023, 4, 6, 1, 0),
#  datetime.datetime(2023, 4, 7, 1, 0),
#  datetime.datetime(2023, 4, 8, 1, 0),
#  datetime.datetime(2023, 4, 9, 1, 0),
#  datetime.datetime(2023, 4, 10, 1, 0),
#  datetime.datetime(2023, 4, 11, 1, 0),
#  datetime.datetime(2023, 4, 12, 1, 0),
#  datetime.datetime(2023, 4, 13, 1, 0),
#  datetime.datetime(2023, 4, 14, 1, 0),
#  datetime.datetime(2023, 4, 15, 1, 0),
#  datetime.datetime(2023, 4, 16, 1, 0),
#  datetime.datetime(2023, 4, 17, 1, 0),
#  datetime.datetime(2023, 4, 18, 1, 0),
#  datetime.datetime(2023, 4, 19, 1, 0),
#  datetime.datetime(2023, 4, 20, 1, 0),
#  datetime.datetime(2023, 4, 21, 1, 0),
#  datetime.datetime(2023, 4, 22, 1, 0),
#  datetime.datetime(2023, 4, 23, 1, 0),
#  datetime.datetime(2023, 4, 24, 1, 0),
#  datetime.datetime(2023, 4, 25, 1, 0),
#  datetime.datetime(2023, 4, 26, 1, 0),
#  datetime.datetime(2023, 4, 27, 1, 0),
#  datetime.datetime(2023, 4, 28, 1, 0),
#  datetime.datetime(2023, 4, 28, 20, 0),
#  datetime.datetime(2023, 4, 29, 14, 0),
#  datetime.datetime(2023, 4, 29, 15, 0),
#  datetime.datetime(2023, 4, 29, 17, 0),
#  datetime.datetime(2023, 4, 29, 23, 0),
#  datetime.datetime(2023, 4, 30, 0, 0),
#  datetime.datetime(2023, 4, 30, 18, 0),
#  datetime.datetime(2023, 5, 1, 1, 0),
#  datetime.datetime(2023, 5, 1, 6, 0),
#  datetime.datetime(2023, 5, 1, 7, 0),
#  datetime.datetime(2023, 5, 1, 17, 0),
#  datetime.datetime(2023, 5, 1, 19, 0),
#  datetime.datetime(2023, 5, 1, 20, 0),
#  datetime.datetime(2023, 5, 2, 15, 0),
#  datetime.datetime(2023, 5, 2, 16, 0),
#  datetime.datetime(2023, 5, 2, 17, 0),
#  datetime.datetime(2023, 5, 3, 3, 0),
#  datetime.datetime(2023, 5, 3, 17, 0),
#  datetime.datetime(2023, 5, 3, 22, 0),
#  datetime.datetime(2023, 5, 4, 6, 0),
#  datetime.datetime(2023, 5, 5, 0, 0),
#  datetime.datetime(2023, 5, 5, 3, 0),
#  datetime.datetime(2023, 5, 5, 5, 0),
#  datetime.datetime(2023, 5, 5, 9, 0),
#  datetime.datetime(2023, 5, 5, 10, 0),
#  datetime.datetime(2023, 5, 5, 16, 0),
#  datetime.datetime(2023, 5, 5, 18, 0),
#  datetime.datetime(2023, 5, 6, 5, 0),
#  datetime.datetime(2023, 5, 6, 10, 0),
#  datetime.datetime(2023, 5, 6, 13, 0),
#  datetime.datetime(2023, 5, 6, 16, 0),
#  datetime.datetime(2023, 5, 6, 17, 0),
#  datetime.datetime(2023, 5, 6, 20, 0),
#  datetime.datetime(2023, 5, 6, 22, 0),
#  datetime.datetime(2023, 5, 6, 23, 0),
#  datetime.datetime(2023, 5, 7, 9, 0),
#  datetime.datetime(2023, 5, 7, 14, 0),
#  datetime.datetime(2023, 5, 7, 22, 0),
#  datetime.datetime(2023, 5, 8, 1, 0),
#  datetime.datetime(2023, 5, 8, 7, 0),
#  datetime.datetime(2023, 5, 8, 21, 0),
#  datetime.datetime(2023, 5, 9, 4, 0),
#  datetime.datetime(2023, 5, 9, 12, 0),
#  datetime.datetime(2023, 5, 9, 13, 0),
#  datetime.datetime(2023, 5, 9, 17, 0),
#  datetime.datetime(2023, 5, 9, 20, 0),
#  datetime.datetime(2023, 5, 10, 13, 0),
#  datetime.datetime(2023, 5, 10, 14, 0),
#  datetime.datetime(2023, 5, 10, 19, 0),
#  datetime.datetime(2023, 5, 12, 5, 0),
#  datetime.datetime(2023, 5, 12, 8, 0),
#  datetime.datetime(2023, 5, 12, 14, 0),
#  datetime.datetime(2023, 5, 13, 7, 0),
#  datetime.datetime(2023, 5, 13, 15, 0),
#  datetime.datetime(2023, 5, 13, 19, 0),
#  datetime.datetime(2023, 5, 14, 2, 0),
#  datetime.datetime(2023, 5, 14, 13, 0),
#  datetime.datetime(2023, 5, 14, 17, 0),
#  datetime.datetime(2023, 5, 14, 19, 0),
#  datetime.datetime(2023, 5, 14, 20, 0),
#  datetime.datetime(2023, 5, 15, 2, 0),
#  datetime.datetime(2023, 5, 15, 5, 0),
#  datetime.datetime(2023, 5, 15, 6, 0),
#  datetime.datetime(2023, 5, 15, 13, 0),
#  datetime.datetime(2023, 5, 15, 15, 0),
#  datetime.datetime(2023, 5, 15, 17, 0),
#  datetime.datetime(2023, 5, 16, 2, 0),
#  datetime.datetime(2023, 5, 16, 3, 0),
#  datetime.datetime(2023, 5, 16, 12, 0),
#  datetime.datetime(2023, 5, 17, 18, 0),
#  datetime.datetime(2023, 5, 18, 3, 0),
#  datetime.datetime(2023, 5, 18, 4, 0),
#  datetime.datetime(2023, 5, 18, 7, 0),
#  datetime.datetime(2023, 5, 18, 9, 0),
#  datetime.datetime(2023, 5, 18, 13, 0),
#  datetime.datetime(2023, 5, 19, 1, 0),
#  datetime.datetime(2023, 5, 19, 9, 0),
#  datetime.datetime(2023, 5, 20, 0, 0),
#  datetime.datetime(2023, 5, 20, 3, 0),
#  datetime.datetime(2023, 5, 21, 2, 0),
#  datetime.datetime(2023, 5, 21, 9, 0),
#  datetime.datetime(2023, 5, 21, 17, 0),
#  datetime.datetime(2023, 5, 21, 18, 0),
#  datetime.datetime(2023, 5, 21, 19, 0),
#  datetime.datetime(2023, 5, 22, 0, 0),
#  datetime.datetime(2023, 5, 22, 1, 0),
#  datetime.datetime(2023, 5, 22, 5, 0),
#  datetime.datetime(2023, 5, 22, 20, 0),
#  datetime.datetime(2023, 5, 22, 22, 0),
#  datetime.datetime(2023, 5, 23, 6, 0),
#  datetime.datetime(2023, 5, 23, 8, 0),
#  datetime.datetime(2023, 5, 24, 16, 0),
#  datetime.datetime(2023, 5, 24, 17, 0),
#  datetime.datetime(2023, 5, 24, 22, 0),
#  datetime.datetime(2023, 5, 25, 0, 0),
#  datetime.datetime(2023, 5, 25, 6, 0),
#  datetime.datetime(2023, 5, 25, 9, 0),
#  datetime.datetime(2023, 5, 25, 15, 0),
#  datetime.datetime(2023, 5, 26, 0, 0),
#  datetime.datetime(2023, 5, 26, 14, 0),
#  datetime.datetime(2023, 5, 26, 15, 0),
#  datetime.datetime(2023, 5, 26, 21, 0),
#  datetime.datetime(2023, 5, 27, 1, 0),
#  datetime.datetime(2023, 5, 27, 8, 0),
#  datetime.datetime(2023, 5, 27, 11, 0),
#  datetime.datetime(2023, 5, 27, 17, 0),
#  datetime.datetime(2023, 5, 28, 2, 0),
#  datetime.datetime(2023, 5, 28, 5, 0)]

# %%
import requests
r = requests.get("https://steamcommunity.com/market/listings/730/Revolution%20Case")

# %%
r.text.find("176358765")
# Out:
# 71684
